# %% [markdown]
# # Milestone 1 - Data Feed Generation

# %% [markdown]
# ## Step 1: Set up the project structure and define AVRO schemas

# %%
# Step 1: Set up the project structure and define AVRO schemas

import numpy as np
import pandas as pd
import fastavro
import json
import datetime
import random
import time
import os
import uuid
from faker import Faker
from geopy.distance import geodesic
import math

# Define AVRO schemas for ride requests
ride_request_schema = {
    "namespace": "ridehailing.avro",
    "type": "record",
    "name": "RideRequest",
    "fields": [
        {"name": "request_id", "type": "string"},
        {"name": "user_id", "type": "string"},
        {"name": "timestamp", "type": "long"},
        {"name": "pickup_location", "type": {"type": "record", "name": "Location", 
            "fields": [
                {"name": "latitude", "type": "double"},
                {"name": "longitude", "type": "double"}
            ]}
        },
        {"name": "destination", "type": "Location"},
        {"name": "status", "type": {"type": "enum", "name": "RequestStatus", 
            "symbols": ["REQUESTED", "ACCEPTED", "CANCELLED", "COMPLETED"]}},
        {"name": "vehicle_type", "type": "string"},
        {"name": "estimated_fare", "type": "double"},
        {"name": "estimated_duration", "type": "int"},
        {"name": "estimated_distance", "type": "double"},
        {"name": "passenger_count", "type": "int"}
    ]
}

# Define AVRO schema for driver status
driver_status_schema = {
    "namespace": "ridehailing.avro",
    "type": "record",
    "name": "DriverStatus",
    "fields": [
        {"name": "driver_id", "type": "string"},
        {"name": "timestamp", "type": "long"},
        {"name": "current_location", "type": {"type": "record", "name": "Location", 
            "fields": [
                {"name": "latitude", "type": "double"},
                {"name": "longitude", "type": "double"}
            ]}
        },
        {"name": "status", "type": {"type": "enum", "name": "DriverStatus", 
            "symbols": ["AVAILABLE", "BUSY", "OFFLINE", "EN_ROUTE_TO_PICKUP", "WITH_PASSENGER"]}},
        {"name": "vehicle_info", "type": {"type": "record", "name": "Vehicle", 
            "fields": [
                {"name": "vehicle_id", "type": "string"},
                {"name": "vehicle_type", "type": "string"},
                {"name": "capacity", "type": "int"}
            ]}
        },
        {"name": "current_ride_id", "type": ["null", "string"]},
        {"name": "last_update", "type": "long"},
        {"name": "battery_level", "type": ["null", "double"]}
    ]
}

# Create directory structure for output data
os.makedirs('data/json/ride_requests', exist_ok=True)
os.makedirs('data/json/driver_status', exist_ok=True)
os.makedirs('data/avro/ride_requests', exist_ok=True)
os.makedirs('data/avro/driver_status', exist_ok=True)

print("Project structure and AVRO schemas set up successfully!")
# Out:
# Project structure and AVRO schemas set up successfully!

# %% [markdown]
# ## Step 2: Implement the CityGrid class

# %%
# Step 2: Implement the CityGrid class

class CityGrid:
    def __init__(self, lat_range=(40.70, 40.85), lon_range=(-74.05, -73.90)):
        """
        Initialize a city grid with hotspots
        Default coordinates approximate New York City
        """
        self.lat_range = lat_range
        self.lon_range = lon_range
        
        # Define hotspots (business districts, residential areas, entertainment zones)
        self.hotspots = {
            'business_districts': [
                {'center': (40.75, -73.98), 'radius': 0.02, 'name': 'Midtown'}, # Midtown
                {'center': (40.71, -74.01), 'radius': 0.015, 'name': 'Financial District'}, # Financial District
            ],
            'residential_areas': [
                {'center': (40.78, -73.95), 'radius': 0.025, 'name': 'Upper East Side'}, # Upper East Side
                {'center': (40.73, -73.99), 'radius': 0.02, 'name': 'Greenwich Village'}, # Greenwich Village
                {'center': (40.80, -73.96), 'radius': 0.025, 'name': 'Upper West Side'}, # Upper West Side
            ],
            'entertainment_zones': [
                {'center': (40.76, -73.98), 'radius': 0.015, 'name': 'Times Square'}, # Times Square
                {'center': (40.74, -73.99), 'radius': 0.015, 'name': 'Chelsea'}, # Chelsea
            ],
            'airports': [
                {'center': (40.64, -73.78), 'radius': 0.03, 'name': 'JFK Airport'}, # JFK Airport
                {'center': (40.77, -73.87), 'radius': 0.02, 'name': 'LaGuardia Airport'}, # LaGuardia
            ]
        }
        
    def get_random_location(self, hotspot_bias=0.8):
        """
        Generate a random location within the city grid
        With a bias towards hotspots
        """
        if random.random() < hotspot_bias:
            # Select a random hotspot category
            category = random.choice(list(self.hotspots.keys()))
            # Select a random hotspot within that category
            hotspot = random.choice(self.hotspots[category])
            
            # Generate a point within the hotspot radius
            angle = random.uniform(0, 2 * math.pi)
            radius = random.uniform(0, hotspot['radius'])
            
            # Convert polar coordinates to lat/lon offset
            lat_offset = radius * math.cos(angle)
            lon_offset = radius * math.sin(angle)
            
            return (
                hotspot['center'][0] + lat_offset,
                hotspot['center'][1] + lon_offset
            )
        else:
            # Generate a completely random location within the city bounds
            return (
                random.uniform(self.lat_range[0], self.lat_range[1]),
                random.uniform(self.lon_range[0], self.lon_range[1])
            )
    
    def get_hotspot_demand_factor(self, location, time_of_day):
        """
        Calculate demand factor based on location and time of day
        Returns a multiplier for ride request probability
        """
        lat, lon = location
        demand_factor = 1.0
        
        # Check if location is in or near a hotspot
        for category, hotspots in self.hotspots.items():
            for hotspot in hotspots:
                distance = geodesic(
                    (lat, lon), 
                    hotspot['center']
                ).kilometers
                
                # If within hotspot radius, adjust demand factor
                if distance <= hotspot['radius'] * 111:  # Convert degrees to km approximately
                    if category == 'business_districts':
                        # Higher demand during morning and evening rush hours
                        if 7 <= time_of_day.hour < 10:  # Morning rush
                            demand_factor += 2.0
                        elif 16 <= time_of_day.hour < 19:  # Evening rush
                            demand_factor += 2.5
                        elif 12 <= time_of_day.hour < 14:  # Lunch time
                            demand_factor += 1.5
                        elif 22 <= time_of_day.hour or time_of_day.hour < 5:  # Late night
                            demand_factor += 0.2
                    
                    elif category == 'residential_areas':
                        # Higher demand in early morning and evening
                        if 6 <= time_of_day.hour < 9:  # Early morning
                            demand_factor += 1.8
                        elif 17 <= time_of_day.hour < 20:  # Evening return
                            demand_factor += 1.2
                    
                    elif category == 'entertainment_zones':
                        # Higher demand in evenings and late night
                        if 18 <= time_of_day.hour < 22:  # Evening
                            demand_factor += 2.0
                        elif 22 <= time_of_day.hour or time_of_day.hour < 3:  # Late night
                            demand_factor += 3.0
                    
                    elif category == 'airports':
                        # Steady demand throughout day with slight peaks
                        demand_factor += 1.0
                        if 7 <= time_of_day.hour < 10 or 16 <= time_of_day.hour < 20:
                            demand_factor += 0.5
        
        return max(0.1, demand_factor)  # Ensure minimum demand factor

    def calculate_trip_details(self, pickup, destination):
        """
        Calculate estimated trip duration, distance and fare
        """
        # Calculate distance in kilometers
        distance_km = geodesic(pickup, destination).kilometers
        
        # Estimate duration (assume average speed of 25 km/h in city)
        # Add random variation to account for traffic
        avg_speed = random.uniform(15, 35)  # km/h
        duration_minutes = (distance_km / avg_speed) * 60
        
        # Add random traffic delay (0-10 minutes)
        duration_minutes += random.uniform(0, 10)
        
        # Calculate fare
        base_fare = 2.50
        per_km_rate = 1.75
        per_minute_rate = 0.35
        
        fare = base_fare + (distance_km * per_km_rate) + (duration_minutes * per_minute_rate)
        
        # Round values
        distance_km = round(distance_km, 2)
        duration_minutes = int(round(duration_minutes))
        fare = round(fare, 2)
        
        return {
            'distance': distance_km,
            'duration': duration_minutes,
            'fare': fare
        }

# Test the CityGrid class
if __name__ == "__main__":
    city = CityGrid()
    test_location = city.get_random_location()
    print(f"Random location: {test_location}")
    
    test_time = datetime.datetime.now()
    demand = city.get_hotspot_demand_factor(test_location, test_time)
    print(f"Demand factor at {test_time.hour}:00: {demand}")
    
    pickup = city.get_random_location()
    destination = city.get_random_location()
    trip = city.calculate_trip_details(pickup, destination)
    print(f"Trip from {pickup} to {destination}:")
    print(f"  Distance: {trip['distance']} km")
    print(f"  Duration: {trip['duration']} minutes")
    print(f"  Fare: ${trip['fare']}")
# Out:
# Random location: (40.75601220134024, -73.99056262201339)
# Demand factor at 11:00: 1.0
# Trip from (40.75578599882364, -73.9552958230431) to (40.77101308675731, -73.94244789690988):
#   Distance: 2.01 km
#   Duration: 12 minutes
#   Fare: $10.08

# %% [markdown]
# ## Step 3: Implement the core RideHailingDataGenerator class

# %%
# Step 3: Implement the core RideHailingDataGenerator class

class RideHailingDataGenerator:
    def __init__(self, config):
        """
        Initialize the ride-hailing data generator with configuration
        
        Parameters:
        -----------
        config : dict
            Configuration dictionary with parameters like:
            - num_drivers: Number of drivers to simulate
            - num_users: Number of users to simulate
            - start_time: Simulation start time (format: 'YYYY-MM-DD HH:MM:SS')
            - base_request_rate: Average number of requests per minute
        """
        self.config = config
        self.faker = Faker()
        self.city_grid = CityGrid()
        self.current_time = datetime.datetime.strptime(config['start_time'], '%Y-%m-%d %H:%M:%S')
        
        # Vehicle types with their capacities - define this BEFORE initializing drivers
        self.vehicle_types = {
            'Economy': 4,
            'Comfort': 4,
            'Premium': 4,
            'SUV': 6,
            'Van': 8
        }
        
        # Initialize drivers and users
        self.drivers = self._initialize_drivers(config['num_drivers'])
        self.users = self._initialize_users(config['num_users'])
        
        # Active rides tracking
        self.active_rides = {}  # request_id -> ride details
        
        print(f"Initialized RideHailingDataGenerator with {len(self.drivers)} drivers and {len(self.users)} users")
        
    def _initialize_drivers(self, num_drivers):
        """
        Initialize driver pool with random attributes
        
        Parameters:
        -----------
        num_drivers : int
            Number of drivers to initialize
            
        Returns:
        --------
        dict
            Dictionary of driver_id -> driver_details
        """
        drivers = {}
        
        for _ in range(num_drivers):
            driver_id = f"D-{str(uuid.uuid4())[:8]}"
            location = self.city_grid.get_random_location()
            
            # Randomly select vehicle type
            vehicle_type = random.choice(list(self.vehicle_types.keys()))
            
            # Initial status distribution: 60% available, 30% busy, 10% offline
            status = random.choices(
                ['AVAILABLE', 'BUSY', 'OFFLINE'], 
                weights=[0.6, 0.3, 0.1]
            )[0]
            
            drivers[driver_id] = {
                'driver_id': driver_id,
                'current_location': {
                    'latitude': location[0],
                    'longitude': location[1]
                },
                'status': status,
                'vehicle_info': {
                    'vehicle_id': f"V-{str(uuid.uuid4())[:8]}",
                    'vehicle_type': vehicle_type,
                    'capacity': self.vehicle_types[vehicle_type]
                },
                'current_ride_id': None,
                'last_update': int(self.current_time.timestamp()),
                'battery_level': random.uniform(0.3, 1.0)
            }
        
        return drivers
    
    def _initialize_users(self, num_users):
        """
        Initialize user pool with random attributes
        
        Parameters:
        -----------
        num_users : int
            Number of users to initialize
            
        Returns:
        --------
        dict
            Dictionary of user_id -> user_details
        """
        users = {}
        
        for _ in range(num_users):
            user_id = f"U-{str(uuid.uuid4())[:8]}"
            
            # Generate home and work locations (typically in residential and business areas)
            home_location = self.city_grid.get_random_location(hotspot_bias=0.9)
            work_location = self.city_grid.get_random_location(hotspot_bias=0.9)
            
            # Preferred vehicle type (weighted towards economy)
            preferred_vehicle_type = random.choices(
                list(self.vehicle_types.keys()), 
                weights=[0.5, 0.25, 0.15, 0.07, 0.03]
            )[0]
            
            users[user_id] = {
                'user_id': user_id,
                'name': self.faker.name(),
                'home_location': home_location,
                'work_location': work_location,
                'preferred_vehicle_type': preferred_vehicle_type,
                'cancellation_probability': random.uniform(0.02, 0.08),  # 2-8% chance to cancel
                'last_activity': int(self.current_time.timestamp())
            }
        
        return users

# Test the RideHailingDataGenerator initialization
if __name__ == "__main__":
    config = {
        'num_drivers': 10,  # Small number for testing
        'num_users': 50,    # Small number for testing
        'start_time': '2023-03-01 08:00:00',
        'base_request_rate': 5  # Average requests per minute
    }
    
    generator = RideHailingDataGenerator(config)
    
    # Print a sample driver
    sample_driver_id = list(generator.drivers.keys())[0]
    print("\nSample Driver:")
    print(json.dumps(generator.drivers[sample_driver_id], indent=2))
    
    # Print a sample user
    sample_user_id = list(generator.users.keys())[0]
    print("\nSample User:")
    print(json.dumps(generator.users[sample_user_id], indent=2))
# Out:
# Initialized RideHailingDataGenerator with 10 drivers and 50 users
#
# Sample Driver:
# {
#   "driver_id": "D-1abb8413",
#   "current_location": {
#     "latitude": 40.7486351276492,
#     "longitude": -73.98574113010186
#   },
#   "status": "BUSY",
#   "vehicle_info": {
#     "vehicle_id": "V-791389af",
#     "vehicle_type": "Premium",
#     "capacity": 4
#   },
#   "current_ride_id": null,
#   "last_update": 1677654000,
#   "battery_level": 0.3741492170311884
# }
#
# Sample User:
# {
#   "user_id": "U-a37ecc9c",
#   "name": "Jesus Palmer",
#   "home_location": [
#     40.77249442631335,
#     -73.87157506799412
#   ],
#   "work_location": [
#     40.75997029257859,
#     -73.98706024920546
#   ],
#   "preferred_vehicle_type": "SUV",
#   "cancellation_probability": 0.07186629781386039,
#   "last_activity": 1677654000
# }

# %% [markdown]
# ## Step 4: Implement ride request generation

# %%
# Step 4: Implement ride request generation

def _get_time_factors(self):
    """
    Calculate time-based factors affecting ride demand
    
    Returns:
    --------
    dict
        Dictionary of time-based factors affecting demand
    """
    hour = self.current_time.hour
    weekday = self.current_time.weekday()  # 0=Monday, 6=Sunday
    
    # Base demand by hour (24-hour format)
    hourly_factors = {
        0: 0.4, 1: 0.3, 2: 0.2, 3: 0.1, 4: 0.1, 5: 0.2,
        6: 0.5, 7: 1.5, 8: 2.0, 9: 1.8, 10: 1.0, 11: 1.0,
        12: 1.2, 13: 1.2, 14: 1.0, 15: 1.0, 16: 1.5, 17: 2.0,
        18: 1.8, 19: 1.5, 20: 1.3, 21: 1.2, 22: 1.0, 23: 0.7
    }
    
    # Weekend vs weekday factors
    weekday_factor = 1.0 if weekday < 5 else 1.3
    
    # Special events (randomly occurring)
    special_event_factor = 1.0
    if random.random() < 0.05:  # 5% chance of special event
        special_event_factor = random.uniform(1.5, 3.0)
        print(f"Special event occurring at {self.current_time}! Demand multiplier: {special_event_factor:.2f}")
    
    # Weather effect (randomly occurring)
    weather_factor = 1.0
    if random.random() < 0.1:  # 10% chance of bad weather
        weather_factor = random.uniform(1.2, 1.8)
        print(f"Bad weather at {self.current_time}! Demand multiplier: {weather_factor:.2f}")
    
    return {
        'hourly': hourly_factors.get(hour, 1.0),
        'weekday': weekday_factor,
        'special_event': special_event_factor,
        'weather': weather_factor
    }

def generate_ride_requests(self):
    """
    Generate ride requests based on time of day, location, etc.
    
    Returns:
    --------
    list
        List of generated ride request events
    """
    time_factors = self._get_time_factors()
    
    # Calculate base request rate per minute
    base_rate = self.config['base_request_rate']
    adjusted_rate = base_rate * time_factors['hourly'] * time_factors['weekday'] * \
                   time_factors['special_event'] * time_factors['weather']
    
    # Determine number of requests to generate this minute
    num_requests = np.random.poisson(adjusted_rate)
    
    requests = []
    for _ in range(num_requests):
        # Select a random user
        user_id = random.choice(list(self.users.keys()))
        user = self.users[user_id]
        
        # Determine pickup location (biased towards user's home/work during certain hours)
        hour = self.current_time.hour
        if 6 <= hour < 10 and random.random() < 0.7:  # Morning commute
            pickup = user['home_location']
            destination = user['work_location']
        elif 16 <= hour < 19 and random.random() < 0.7:  # Evening commute
            pickup = user['work_location']
            destination = user['home_location']
        else:
            # Random locations with hotspot bias
            pickup = self.city_grid.get_random_location()
            destination = self.city_grid.get_random_location()
            
            # Ensure pickup and destination are not too close
            while geodesic(pickup, destination).kilometers < 1.0:
                destination = self.city_grid.get_random_location()
        
        # Calculate trip details
        trip_details = self.city_grid.calculate_trip_details(pickup, destination)
        
        # Generate request
        request_id = f"R-{str(uuid.uuid4())}"
        timestamp = int(self.current_time.timestamp())
        
        request = {
            'request_id': request_id,
            'user_id': user_id,
            'timestamp': timestamp,
            'pickup_location': {
                'latitude': pickup[0],
                'longitude': pickup[1]
            },
            'destination': {
                'latitude': destination[0],
                'longitude': destination[1]
            },
            'status': 'REQUESTED',
            'vehicle_type': user['preferred_vehicle_type'],
            'estimated_fare': trip_details['fare'],
            'estimated_duration': trip_details['duration'],
            'estimated_distance': trip_details['distance'],
            'passenger_count': random.randint(1, self.vehicle_types[user['preferred_vehicle_type']])
        }
        
        # Add to active rides
        self.active_rides[request_id] = {
            'request': request,
            'assigned_driver': None,
            'status': 'REQUESTED',
            'created_at': self.current_time,
            'pickup_time': None,
            'completion_time': None
        }
        
        requests.append(request)
    
    if requests:
        print(f"Generated {len(requests)} ride requests at {self.current_time}")
    
    return requests

# Add these methods to the RideHailingDataGenerator class
RideHailingDataGenerator._get_time_factors = _get_time_factors
RideHailingDataGenerator.generate_ride_requests = generate_ride_requests

# Test ride request generation
if __name__ == "__main__":
    config = {
        'num_drivers': 10,
        'num_users': 50,
        'start_time': '2023-03-01 08:00:00',  # Morning rush hour
        'base_request_rate': 5  # Average requests per minute
    }
    
    generator = RideHailingDataGenerator(config)
    
    # Generate ride requests for the current time
    ride_requests = generator.generate_ride_requests()
    
    # Print a sample ride request
    if ride_requests:
        print("\nSample Ride Request:")
        print(json.dumps(ride_requests[0], indent=2))
        
        print(f"\nTotal active rides: {len(generator.active_rides)}")
    else:
        print("No ride requests generated in this iteration.")
# Out:
# Initialized RideHailingDataGenerator with 10 drivers and 50 users
# Generated 4 ride requests at 2023-03-01 08:00:00
#
# Sample Ride Request:
# {
#   "request_id": "R-939722f9-0d36-4a5c-ab2a-c06c6a2915bf",
#   "user_id": "U-79aaa849",
#   "timestamp": 1677654000,
#   "pickup_location": {
#     "latitude": 40.629296252415465,
#     "longitude": -73.79278698281433
#   },
#   "destination": {
#     "latitude": 40.77132018876232,
#     "longitude": -73.86657707425255
#   },
#   "status": "REQUESTED",
#   "vehicle_type": "Premium",
#   "estimated_fare": 45.49,
#   "estimated_duration": 38,
#   "estimated_distance": 16.96,
#   "passenger_count": 4
# }
#
# Total active rides: 4

# %% [markdown]
# ## Step 5: Implement driver status updates and ride matching

# %%
# Step 5: Implement driver status updates and ride matching

def update_driver_statuses(self):
    """
    Update driver locations and statuses
    Match available drivers with ride requests
    
    Returns:
    --------
    list
        List of driver status update events
    """
    driver_updates = []
    
    # First, process ride matching for pending requests
    self._match_drivers_to_requests()
    
    # Then update all drivers
    for driver_id, driver in self.drivers.items():
        # Skip drivers who are offline
        if driver['status'] == 'OFFLINE':
            # 5% chance of coming online
            if random.random() < 0.05:
                driver['status'] = 'AVAILABLE'
                print(f"Driver {driver_id} came online")
            else:
                continue
        
        # Update timestamp
        timestamp = int(self.current_time.timestamp())
        driver['last_update'] = timestamp
        
        # Update location based on status
        current_lat = driver['current_location']['latitude']
        current_lon = driver['current_location']['longitude']
        
        if driver['status'] == 'AVAILABLE':
            # Move randomly, with bias towards hotspots
            if random.random() < 0.7:  # 70% chance to move towards hotspots
                # Get a random hotspot
                category = random.choice(list(self.city_grid.hotspots.keys()))
                hotspot = random.choice(self.city_grid.hotspots[category])
                
                # Move slightly towards the hotspot
                target_lat, target_lon = hotspot['center']
                
                # Calculate direction vector
                direction_lat = target_lat - current_lat
                direction_lon = target_lon - current_lon
                
                # Normalize and scale (simulate driving at ~20-30 km/h)
                distance = ((direction_lat ** 2) + (direction_lon ** 2)) ** 0.5
                if distance > 0:
                    # Convert to unit vector and scale
                    # ~0.0005 degrees is roughly 50 meters
                    scale = min(distance, 0.0005) / distance
                    new_lat = current_lat + (direction_lat * scale)
                    new_lon = current_lon + (direction_lon * scale)
                else:
                    # If already at hotspot, move randomly
                    new_lat = current_lat + random.uniform(-0.0005, 0.0005)
                    new_lon = current_lon + random.uniform(-0.0005, 0.0005)
            else:
                # Random movement
                new_lat = current_lat + random.uniform(-0.0005, 0.0005)
                new_lon = current_lon + random.uniform(-0.0005, 0.0005)
                
            # Ensure we stay within city bounds
            new_lat = max(self.city_grid.lat_range[0], min(new_lat, self.city_grid.lat_range[1]))
            new_lon = max(self.city_grid.lon_range[0], min(new_lon, self.city_grid.lon_range[1]))
            
            driver['current_location']['latitude'] = new_lat
            driver['current_location']['longitude'] = new_lon
            
        elif driver['status'] == 'EN_ROUTE_TO_PICKUP':
            # Driver is heading to pickup a passenger
            ride_id = driver['current_ride_id']
            if ride_id and ride_id in self.active_rides:
                ride = self.active_rides[ride_id]
                pickup_lat = ride['request']['pickup_location']['latitude']
                pickup_lon = ride['request']['pickup_location']['longitude']
                
                # Calculate direction to pickup
                direction_lat = pickup_lat - current_lat
                direction_lon = pickup_lon - current_lon
                
                # Calculate distance to pickup
                distance = ((direction_lat ** 2) + (direction_lon ** 2)) ** 0.5
                
                if distance < 0.0001:  # ~10 meters, driver has arrived at pickup
                    # Update ride status
                    ride['status'] = 'PICKUP_ARRIVED'
                    ride['pickup_time'] = self.current_time
                    ride['request']['status'] = 'ACCEPTED'
                    
                    # Update driver status
                    driver['status'] = 'WITH_PASSENGER'
                    print(f"Driver {driver_id} arrived at pickup for ride {ride_id}")
                else:
                    # Move towards pickup
                    # Scale movement (faster than cruising)
                    scale = min(distance, 0.001) / distance
                    new_lat = current_lat + (direction_lat * scale)
                    new_lon = current_lon + (direction_lon * scale)
                    
                    driver['current_location']['latitude'] = new_lat
                    driver['current_location']['longitude'] = new_lon
            else:
                # Something went wrong, reset driver
                driver['status'] = 'AVAILABLE'
                driver['current_ride_id'] = None
                print(f"Driver {driver_id} reset due to invalid ride reference")
                
        elif driver['status'] == 'WITH_PASSENGER':
            # Driver is taking passenger to destination
            ride_id = driver['current_ride_id']
            if ride_id and ride_id in self.active_rides:
                ride = self.active_rides[ride_id]
                dest_lat = ride['request']['destination']['latitude']
                dest_lon = ride['request']['destination']['longitude']
                
                # Calculate direction to destination
                direction_lat = dest_lat - current_lat
                direction_lon = dest_lon - current_lon
                
                # Calculate distance to destination
                distance = ((direction_lat ** 2) + (direction_lon ** 2)) ** 0.5
                
                if distance < 0.0001:  # ~10 meters, driver has arrived at destination
                    # Update ride status
                    ride['status'] = 'COMPLETED'
                    ride['completion_time'] = self.current_time
                    ride['request']['status'] = 'COMPLETED'
                    
                    # Update driver status
                    driver['status'] = 'AVAILABLE'
                    driver['current_ride_id'] = None
                    print(f"Driver {driver_id} completed ride {ride_id}")
                else:
                    # Move towards destination
                    # Scale movement (faster than cruising)
                    scale = min(distance, 0.001) / distance
                    new_lat = current_lat + (direction_lat * scale)
                    new_lon = current_lon + (direction_lon * scale)
                    
                    driver['current_location']['latitude'] = new_lat
                    driver['current_location']['longitude'] = new_lon
            else:
                # Something went wrong, reset driver
                driver['status'] = 'AVAILABLE'
                driver['current_ride_id'] = None
                print(f"Driver {driver_id} reset due to invalid ride reference")
        
        # Random chance for driver to go offline if available
        if driver['status'] == 'AVAILABLE' and random.random() < 0.01:  # 1% chance per minute
            driver['status'] = 'OFFLINE'
            print(f"Driver {driver_id} went offline")
        
        # Create driver status update event
        driver_update = {
            'driver_id': driver_id,
            'timestamp': timestamp,
            'current_location': driver['current_location'],
            'status': driver['status'],
            'vehicle_info': driver['vehicle_info'],
            'current_ride_id': driver['current_ride_id'],
            'last_update': driver['last_update'],
            'battery_level': driver['battery_level']
        }
        
        driver_updates.append(driver_update)
    
    return driver_updates

def _match_drivers_to_requests(self):
    """
    Match available drivers with pending ride requests
    """
    # Get all pending ride requests
    pending_requests = {
        req_id: ride for req_id, ride in self.active_rides.items() 
        if ride['status'] == 'REQUESTED' and ride['assigned_driver'] is None
    }
    
    if not pending_requests:
        return
    
    # Get all available drivers
    available_drivers = {
        driver_id: driver for driver_id, driver in self.drivers.items()
        if driver['status'] == 'AVAILABLE'
    }
    
    if not available_drivers:
        return
    
    # Sort requests by timestamp (oldest first)
    sorted_requests = sorted(
        pending_requests.items(),
        key=lambda x: x[1]['created_at']
    )
    
    # For each request, find the closest available driver with matching vehicle type
    for request_id, ride in sorted_requests:
        request = ride['request']
        required_vehicle_type = request['vehicle_type']
        pickup_location = (
            request['pickup_location']['latitude'],
            request['pickup_location']['longitude']
        )
        
        # Find drivers with matching vehicle type
        matching_drivers = {
            driver_id: driver for driver_id, driver in available_drivers.items()
            if driver['vehicle_info']['vehicle_type'] == required_vehicle_type
        }
        
        # If no exact match, consider any available driver
        if not matching_drivers:
            matching_drivers = available_drivers
        
        # Find closest driver
        closest_driver_id = None
        min_distance = float('inf')
        
        for driver_id, driver in matching_drivers.items():
            driver_location = (
                driver['current_location']['latitude'],
                driver['current_location']['longitude']
            )
            
            distance = geodesic(driver_location, pickup_location).kilometers
            
            if distance < min_distance:
                min_distance = distance
                closest_driver_id = driver_id
        
        # If we found a driver within reasonable distance (10km)
        if closest_driver_id and min_distance <= 10:
            # Assign driver to ride
            ride['assigned_driver'] = closest_driver_id
            ride['status'] = 'DRIVER_ASSIGNED'
            
            # Update driver status
            driver = self.drivers[closest_driver_id]
            driver['status'] = 'EN_ROUTE_TO_PICKUP'
            driver['current_ride_id'] = request_id
            
            # Remove driver from available pool
            available_drivers.pop(closest_driver_id)
            
            print(f"Matched driver {closest_driver_id} to ride {request_id} (distance: {min_distance:.2f} km)")

# Add these methods to the RideHailingDataGenerator class
RideHailingDataGenerator.update_driver_statuses = update_driver_statuses
RideHailingDataGenerator._match_drivers_to_requests = _match_drivers_to_requests

# Test driver updates and matching
if __name__ == "__main__":
    config = {
        'num_drivers': 20,  # More drivers for better matching
        'num_users': 50,
        'start_time': '2023-03-01 08:00:00',
        'base_request_rate': 5
    }
    
    generator = RideHailingDataGenerator(config)
    
    # Generate some ride requests
    ride_requests = generator.generate_ride_requests()
    
    # Update driver statuses and match with requests
    driver_updates = generator.update_driver_statuses()
    
    # Print matching results
    print("\nActive Rides Status:")
    for ride_id, ride in generator.active_rides.items():
        print(f"Ride {ride_id}: Status={ride['status']}, Driver={ride['assigned_driver']}")
    
    # Print a sample driver update
    if driver_updates:
        print("\nSample Driver Update:")
        print(json.dumps(driver_updates[0], indent=2))
# Out:
# Initialized RideHailingDataGenerator with 20 drivers and 50 users
# Generated 6 ride requests at 2023-03-01 08:00:00
# Matched driver D-56583691 to ride R-1635c21b-a7ab-4830-830f-eb9d63b88964 (distance: 1.37 km)
# Matched driver D-f931fda0 to ride R-38c7a13f-355f-471c-8a3e-8e68fad1d767 (distance: 3.98 km)
# Matched driver D-0b625d05 to ride R-2b208e4b-7aba-41b1-b806-f13a5008f318 (distance: 0.34 km)
# Matched driver D-2bf5976e to ride R-1dd17352-832a-4ff6-9d6c-0b1d327ec89c (distance: 2.52 km)
#
# Active Rides Status:
# Ride R-1635c21b-a7ab-4830-830f-eb9d63b88964: Status=DRIVER_ASSIGNED, Driver=D-56583691
# Ride R-38c7a13f-355f-471c-8a3e-8e68fad1d767: Status=DRIVER_ASSIGNED, Driver=D-f931fda0
# Ride R-1ad9eaa5-9772-4582-aaf6-d67d70ad9327: Status=REQUESTED, Driver=None
# Ride R-1cda35ef-9820-4e5a-a943-21af5cb2274f: Status=REQUESTED, Driver=None
# Ride R-2b208e4b-7aba-41b1-b806-f13a5008f318: Status=DRIVER_ASSIGNED, Driver=D-0b625d05
# Ride R-1dd17352-832a-4ff6-9d6c-0b1d327ec89c: Status=DRIVER_ASSIGNED, Driver=D-2bf5976e
#
# Sample Driver Update:
# {
#   "driver_id": "D-04cc12ed",
#   "timestamp": 1677654000,
#   "current_location": {
#     "latitude": 40.83334212582509,
#     "longitude": -73.91682341023746
#   },
#   "status": "AVAILABLE",
#   "vehicle_info": {
#     "vehicle_id": "V-d31501ab",
#     "vehicle_type": "Premium",
#     "capacity": 4
#   },
#   "current_ride_id": null,
#   "last_update": 1677654000,
#   "battery_level": 0.8062982500682874
# }

# %% [markdown]
# ## Step 6: Implement ride lifecycle management

# %%
# Step 6: Implement ride lifecycle management

def process_ride_lifecycle_events(self):
    """
    Process ride lifecycle events: cancellations, completions, etc.
    
    Returns:
    --------
    list
        List of ride status update events
    """
    ride_updates = []
    rides_to_remove = []
    
    for ride_id, ride in self.active_rides.items():
        request = ride['request']
        status = ride['status']
        user_id = request['user_id']
        user = self.users[user_id]
        
        # Process based on current status
        if status == 'REQUESTED':
            # Ride is waiting for a driver
            # Check if user cancels
            wait_time = (self.current_time - ride['created_at']).total_seconds() / 60  # in minutes
            
            # Increasing cancellation probability the longer they wait
            cancel_prob = user['cancellation_probability'] * (1 + wait_time / 5)
            
            if random.random() < cancel_prob:
                # User cancels the ride
                ride['status'] = 'CANCELLED'
                request['status'] = 'CANCELLED'
                print(f"User {user_id} cancelled ride {ride_id} after waiting {wait_time:.1f} minutes")
                
                ride_update = request.copy()
                ride_updates.append(ride_update)
                
                # Mark for removal from active rides
                rides_to_remove.append(ride_id)
            
            # If waiting too long (>15 min), auto-cancel
            elif wait_time > 25:
                ride['status'] = 'CANCELLED'
                request['status'] = 'CANCELLED'
                print(f"System auto-cancelled ride {ride_id} after excessive wait time ({wait_time:.1f} minutes)")
                
                ride_update = request.copy()
                ride_updates.append(ride_update)
                
                # Mark for removal from active rides
                rides_to_remove.append(ride_id)
                
        elif status == 'DRIVER_ASSIGNED':
            # Driver is assigned but not yet at pickup
            # Small chance of driver cancellation
            if random.random() < 0.02:  # 2% chance per minute
                driver_id = ride['assigned_driver']
                
                if driver_id and driver_id in self.drivers:
                    # Reset driver
                    driver = self.drivers[driver_id]
                    driver['status'] = 'AVAILABLE'
                    driver['current_ride_id'] = None
                
                # Reset ride
                ride['status'] = 'REQUESTED'
                ride['assigned_driver'] = None
                print(f"Driver {driver_id} cancelled assignment to ride {ride_id}")
                
                ride_update = request.copy()
                ride_updates.append(ride_update)
        
        elif status == 'PICKUP_ARRIVED':
            # Driver has arrived at pickup
            # Small chance of user no-show
            if random.random() < 0.05:  # 5% chance
                driver_id = ride['assigned_driver']
                
                if driver_id and driver_id in self.drivers:
                    # Reset driver
                    driver = self.drivers[driver_id]
                    driver['status'] = 'AVAILABLE'
                    driver['current_ride_id'] = None
                
                # Update ride
                ride['status'] = 'CANCELLED'
                request['status'] = 'CANCELLED'
                print(f"User {user_id} no-show for ride {ride_id}")
                
                ride_update = request.copy()
                ride_updates.append(ride_update)
                
                # Mark for removal from active rides
                rides_to_remove.append(ride_id)
            else:
                # User gets in, ride starts
                ride['status'] = 'IN_PROGRESS'
                print(f"Ride {ride_id} started with driver {ride['assigned_driver']}")
                
                ride_update = request.copy()
                ride_updates.append(ride_update)
        
        elif status == 'COMPLETED':
            # Ride is complete, generate final update
            ride_update = request.copy()
            ride_updates.append(ride_update)
            
            # Mark for removal from active rides
            rides_to_remove.append(ride_id)
            
            print(f"Ride {ride_id} completed and removed from active rides")
    
    # Remove completed/cancelled rides
    for ride_id in rides_to_remove:
        self.active_rides.pop(ride_id)
    
    return ride_updates

def get_active_ride_stats(self):
    """
    Get statistics about active rides
    
    Returns:
    --------
    dict
        Dictionary with ride statistics
    """
    status_counts = {
        'REQUESTED': 0,
        'DRIVER_ASSIGNED': 0,
        'PICKUP_ARRIVED': 0,
        'IN_PROGRESS': 0,
        'COMPLETED': 0,
        'CANCELLED': 0
    }
    
    for ride in self.active_rides.values():
        status = ride['status']
        status_counts[status] = status_counts.get(status, 0) + 1
    
    return {
        'total_active': len(self.active_rides),
        'by_status': status_counts
    }

def get_driver_stats(self):
    """
    Get statistics about drivers
    
    Returns:
    --------
    dict
        Dictionary with driver statistics
    """
    status_counts = {
        'AVAILABLE': 0,
        'BUSY': 0,
        'OFFLINE': 0,
        'EN_ROUTE_TO_PICKUP': 0,
        'WITH_PASSENGER': 0
    }
    
    for driver in self.drivers.values():
        status = driver['status']
        status_counts[status] = status_counts.get(status, 0) + 1
    
    return {
        'total_drivers': len(self.drivers),
        'by_status': status_counts
    }

# Add these methods to the RideHailingDataGenerator class
RideHailingDataGenerator.process_ride_lifecycle_events = process_ride_lifecycle_events
RideHailingDataGenerator.get_active_ride_stats = get_active_ride_stats
RideHailingDataGenerator.get_driver_stats = get_driver_stats

# Test ride lifecycle management
if __name__ == "__main__":
    config = {
        'num_drivers': 20,
        'num_users': 50,
        'start_time': '2023-03-01 08:00:00',
        'base_request_rate': 5
    }
    
    generator = RideHailingDataGenerator(config)
    
    # Generate some ride requests
    ride_requests = generator.generate_ride_requests()
    
    # Update driver statuses and match with requests
    driver_updates = generator.update_driver_statuses()
    
    # Process ride lifecycle events
    ride_updates = generator.process_ride_lifecycle_events()
    
    # Print statistics
    print("\nRide Statistics:")
    print(json.dumps(generator.get_active_ride_stats(), indent=2))
    
    print("\nDriver Statistics:")
    print(json.dumps(generator.get_driver_stats(), indent=2))
    
    # Advance time by 5 minutes and process again
    print("\nAdvancing time by 5 minutes...")
    generator.current_time += datetime.timedelta(minutes=5)
    
    # Process ride lifecycle again
    ride_updates = generator.process_ride_lifecycle_events()
    
    # Print updated statistics
    print("\nUpdated Ride Statistics:")
    print(json.dumps(generator.get_active_ride_stats(), indent=2))
# Out:
# Initialized RideHailingDataGenerator with 20 drivers and 50 users
# Generated 12 ride requests at 2023-03-01 08:00:00
# Matched driver D-e219d168 to ride R-42dd5231-14ee-41c0-a6ee-ccdbf15559aa (distance: 2.87 km)
# Matched driver D-db1b9daa to ride R-23e8af22-4e8d-4d99-a614-1c25b258a1d8 (distance: 4.80 km)
# Matched driver D-4bd6bcbd to ride R-3f7e5dcf-534e-41c2-ad65-772b47ce69bb (distance: 7.99 km)
# Matched driver D-ffc695e4 to ride R-2b91e532-00d8-4678-bd0b-8aec12d10dfd (distance: 2.60 km)
# Matched driver D-c0ea640f to ride R-45c30ec8-2554-429d-87e9-3194764adc00 (distance: 1.35 km)
# Matched driver D-99e7ed14 to ride R-d1eff3e2-75c8-4262-b07a-05cc3d95db77 (distance: 3.10 km)
# Matched driver D-52993c8e to ride R-6f72f98b-efc7-4b31-ace3-d6a5b05bffaf (distance: 1.35 km)
# Matched driver D-d282f030 to ride R-6f081966-4061-4a3e-b987-865f0c585f15 (distance: 8.24 km)
# Matched driver D-3f14045d to ride R-808621de-4688-4f08-b741-22606bdd55e9 (distance: 3.26 km)
# Matched driver D-afb9c630 to ride R-c82920b0-9ff9-47fd-954c-51299276e0a5 (distance: 1.67 km)
# Matched driver D-46a02b5d to ride R-4745f719-115c-4965-b56f-4c7a21933fab (distance: 2.66 km)
#
# Ride Statistics:
# {
#   "total_active": 12,
#   "by_status": {
#     "REQUESTED": 1,
#     "DRIVER_ASSIGNED": 11,
#     "PICKUP_ARRIVED": 0,
#     "IN_PROGRESS": 0,
#     "COMPLETED": 0,
#     "CANCELLED": 0
#   }
# }
#
# Driver Statistics:
# {
#   "total_drivers": 20,
#   "by_status": {
#     "AVAILABLE": 5,
#     "BUSY": 4,
#     "OFFLINE": 0,
#     "EN_ROUTE_TO_PICKUP": 11,
#     "WITH_PASSENGER": 0
#   }
# }
#
# Advancing time by 5 minutes...
#
# Updated Ride Statistics:
# {
#   "total_active": 12,
#   "by_status": {
#     "REQUESTED": 1,
#     "DRIVER_ASSIGNED": 11,
#     "PICKUP_ARRIVED": 0,
#     "IN_PROGRESS": 0,
#     "COMPLETED": 0,
#     "CANCELLED": 0
#   }
# }

# %% [markdown]
# ## Step 7: Implement data serialization

# %%
# Step 7: Implement data serialization

# Redefine schemas with unique type names to avoid conflicts
ride_request_schema = {
    "namespace": "ridehailing.avro",
    "type": "record",
    "name": "RideRequest",
    "fields": [
        {"name": "request_id", "type": "string"},
        {"name": "user_id", "type": "string"},
        {"name": "timestamp", "type": "long"},
        {"name": "pickup_location", "type": {"type": "record", "name": "PickupLocation", 
            "fields": [
                {"name": "latitude", "type": "double"},
                {"name": "longitude", "type": "double"}
            ]}
        },
        {"name": "destination", "type": {"type": "record", "name": "DestinationLocation", 
            "fields": [
                {"name": "latitude", "type": "double"},
                {"name": "longitude", "type": "double"}
            ]}
        },
        {"name": "status", "type": {"type": "enum", "name": "RequestStatus", 
            "symbols": ["REQUESTED", "ACCEPTED", "CANCELLED", "COMPLETED"]}},
        {"name": "vehicle_type", "type": "string"},
        {"name": "estimated_fare", "type": "double"},
        {"name": "estimated_duration", "type": "int"},
        {"name": "estimated_distance", "type": "double"},
        {"name": "passenger_count", "type": "int"}
    ]
}

driver_status_schema = {
    "namespace": "ridehailing.avro",
    "type": "record",
    "name": "DriverStatus",
    "fields": [
        {"name": "driver_id", "type": "string"},
        {"name": "timestamp", "type": "long"},
        {"name": "current_location", "type": {"type": "record", "name": "DriverLocation", 
            "fields": [
                {"name": "latitude", "type": "double"},
                {"name": "longitude", "type": "double"}
            ]}
        },
        {"name": "status", "type": {"type": "enum", "name": "DriverStatusEnum", 
            "symbols": ["AVAILABLE", "BUSY", "OFFLINE", "EN_ROUTE_TO_PICKUP", "WITH_PASSENGER"]}},
        {"name": "vehicle_info", "type": {"type": "record", "name": "VehicleInfo", 
            "fields": [
                {"name": "vehicle_id", "type": "string"},
                {"name": "vehicle_type", "type": "string"},
                {"name": "capacity", "type": "int"}
            ]}
        },
        {"name": "current_ride_id", "type": ["null", "string"]},
        {"name": "last_update", "type": "long"},
        {"name": "battery_level", "type": ["null", "double"]}
    ]
}

def serialize_to_json(self, data, data_type, timestamp=None):
    """
    Serialize data to JSON format and save to file
    
    Parameters:
    -----------
    data : list or dict
        Data to serialize
    data_type : str
        Type of data ('ride_requests' or 'driver_status')
    timestamp : datetime, optional
        Timestamp to use in filename, defaults to current_time
    
    Returns:
    --------
    str
        Path to the saved file
    """
    if not data:
        return None
    
    if timestamp is None:
        timestamp = self.current_time
    
    # Create timestamp string for filename
    timestamp_str = timestamp.strftime('%Y%m%d_%H%M%S')
    
    # Create directory if it doesn't exist
    directory = f'data/json/{data_type}'
    os.makedirs(directory, exist_ok=True)
    
    # Create filename
    filename = f'{directory}/{data_type}_{timestamp_str}.json'
    
    # Write data to file
    with open(filename, 'w') as f:
        if isinstance(data, list):
            json.dump(data, f, indent=2)
        else:
            json.dump([data], f, indent=2)
    
    print(f"Saved {len(data) if isinstance(data, list) else 1} {data_type} records to {filename}")
    
    return filename

def serialize_to_avro(self, data, data_type, schema, timestamp=None):
    """
    Serialize data to AVRO format and save to file
    
    Parameters:
    -----------
    data : list or dict
        Data to serialize
    data_type : str
        Type of data ('ride_requests' or 'driver_status')
    schema : dict
        AVRO schema for the data
    timestamp : datetime, optional
        Timestamp to use in filename, defaults to current_time
    
    Returns:
    --------
    str
        Path to the saved file
    """
    if not data:
        return None
    
    if timestamp is None:
        timestamp = self.current_time
    
    # Create timestamp string for filename
    timestamp_str = timestamp.strftime('%Y%m%d_%H%M%S')
    
    # Create directory if it doesn't exist
    directory = f'data/avro/{data_type}'
    os.makedirs(directory, exist_ok=True)
    
    # Create filename
    filename = f'{directory}/{data_type}_{timestamp_str}.avro'
    
    # Prepare data for serialization
    if not isinstance(data, list):
        records = [data]
    else:
        records = data
    
    # Write data to file
    with open(filename, 'wb') as f:
        fastavro.writer(f, schema, records)
    
    print(f"Saved {len(records)} {data_type} records to {filename}")
    
    return filename

def save_data_batch(self, ride_requests, driver_updates):
    """
    Save a batch of ride requests and driver updates to both JSON and AVRO formats
    
    Parameters:
    -----------
    ride_requests : list
        List of ride request events
    driver_updates : list
        List of driver status update events
    
    Returns:
    --------
    dict
        Dictionary with paths to saved files
    """
    saved_files = {}
    
    # Save ride requests
    if ride_requests:
        saved_files['ride_requests_json'] = self.serialize_to_json(
            ride_requests, 'ride_requests'
        )
        saved_files['ride_requests_avro'] = self.serialize_to_avro(
            ride_requests, 'ride_requests', ride_request_schema
        )
    
    # Save driver updates
    if driver_updates:
        saved_files['driver_status_json'] = self.serialize_to_json(
            driver_updates, 'driver_status'
        )
        saved_files['driver_status_avro'] = self.serialize_to_avro(
            driver_updates, 'driver_status', driver_status_schema
        )
    
    return saved_files

# Add these methods to the RideHailingDataGenerator class
RideHailingDataGenerator.serialize_to_json = serialize_to_json
RideHailingDataGenerator.serialize_to_avro = serialize_to_avro
RideHailingDataGenerator.save_data_batch = save_data_batch

# Test data serialization
if __name__ == "__main__":
    config = {
        'num_drivers': 10,
        'num_users': 30,
        'start_time': '2023-03-01 08:00:00',
        'base_request_rate': 3
    }
    
    generator = RideHailingDataGenerator(config)
    
    # Generate some ride requests
    ride_requests = generator.generate_ride_requests()
    
    # Update driver statuses
    driver_updates = generator.update_driver_statuses()
    
    # Save data
    if ride_requests or driver_updates:
        saved_files = generator.save_data_batch(ride_requests, driver_updates)
        print("\nSaved files:")
        for file_type, file_path in saved_files.items():
            print(f"  {file_type}: {file_path}")
    else:
        print("No data to save in this batch")
# Out:
# Initialized RideHailingDataGenerator with 10 drivers and 30 users
# Generated 5 ride requests at 2023-03-01 08:00:00
# Matched driver D-2734d58e to ride R-b4a596b7-da4e-4e8e-9cdb-859bb63b865b (distance: 3.73 km)
# Matched driver D-19eb04cd to ride R-d97dcef2-5b7b-4c14-b3b5-7340bc56cace (distance: 1.43 km)
# Matched driver D-e4d976f8 to ride R-c312c327-8f07-4fda-8526-48e634f03238 (distance: 2.90 km)
# Matched driver D-03d17ae2 to ride R-93765352-5e0f-4f33-8a17-d1cdff2992ff (distance: 0.73 km)
# Matched driver D-0de2dfd7 to ride R-ff5ccdca-b380-46a1-beb5-f202c0a02e22 (distance: 4.39 km)
# Saved 5 ride_requests records to data/json/ride_requests/ride_requests_20230301_080000.json
# Saved 5 ride_requests records to data/avro/ride_requests/ride_requests_20230301_080000.avro
# Saved 10 driver_status records to data/json/driver_status/driver_status_20230301_080000.json
# Saved 10 driver_status records to data/avro/driver_status/driver_status_20230301_080000.avro
#
# Saved files:
#   ride_requests_json: data/json/ride_requests/ride_requests_20230301_080000.json
#   ride_requests_avro: data/avro/ride_requests/ride_requests_20230301_080000.avro
#   driver_status_json: data/json/driver_status/driver_status_20230301_080000.json
#   driver_status_avro: data/avro/driver_status/driver_status_20230301_080000.avro

# %% [markdown]
# ## Step 8: Implement the simulation runner

# %%
# Step 8: Implement the simulation runner with fixed statistics tracking

def run_simulation(self, duration_minutes, time_step_seconds=60, verbose=True):
    """
    Run the ride-hailing simulation for a specified duration
    """
    start_time = self.current_time
    end_time = start_time + datetime.timedelta(minutes=duration_minutes)
    
    # Statistics tracking
    stats = {
        'total_requests': 0,
        'completed_rides': 0,
        'cancelled_rides': 0,
        'total_fare': 0.0,
        'avg_wait_time': 0.0,
        'avg_ride_duration': 0.0,
        'ride_requests_by_hour': {},
        'saved_files': []
    }
    
    # Temporary storage for wait times and ride durations
    wait_times = []
    ride_durations = []
    
    # Track completed and cancelled rides separately
    completed_ride_ids = set()
    
    print(f"Starting simulation at {start_time} for {duration_minutes} minutes")
    print(f"Initial state: {len(self.drivers)} drivers, {len(self.users)} users")
    
    # Main simulation loop
    while self.current_time < end_time:
        # Generate ride requests
        ride_requests = self.generate_ride_requests()
        stats['total_requests'] += len(ride_requests)
        
        # Update driver statuses
        driver_updates = self.update_driver_statuses()
        
        # Process ride lifecycle events
        ride_updates = self.process_ride_lifecycle_events()
        
        # Check for completed rides in the updates
        for update in ride_updates:
            if update['status'] == 'COMPLETED' and update['request_id'] not in completed_ride_ids:
                stats['completed_rides'] += 1
                stats['total_fare'] += update['estimated_fare']
                completed_ride_ids.add(update['request_id'])
            elif update['status'] == 'CANCELLED':
                stats['cancelled_rides'] += 1
        
        # Also check for completed rides in the active_rides that are about to be removed
        for ride_id, ride in list(self.active_rides.items()):
            if ride['status'] == 'COMPLETED' and ride_id not in completed_ride_ids:
                stats['completed_rides'] += 1
                stats['total_fare'] += ride['request']['estimated_fare']
                completed_ride_ids.add(ride_id)
                
                # Calculate wait time and ride duration
                if ride['pickup_time'] and ride['completion_time']:
                    wait_time = (ride['pickup_time'] - ride['created_at']).total_seconds() / 60
                    wait_times.append(wait_time)
                    
                    duration = (ride['completion_time'] - ride['pickup_time']).total_seconds() / 60
                    ride_durations.append(duration)
        
        # Save data batch
        if ride_requests or driver_updates:
            saved_files = self.save_data_batch(ride_requests, driver_updates)
            if saved_files:
                stats['saved_files'].extend(saved_files.values())
        
        # Track statistics
        hour_key = self.current_time.strftime('%Y-%m-%d %H:00')
        if hour_key not in stats['ride_requests_by_hour']:
            stats['ride_requests_by_hour'][hour_key] = 0
        stats['ride_requests_by_hour'][hour_key] += len(ride_requests)
        
        # Print current status if verbose
        if verbose and self.current_time.minute % 5 == 0 and self.current_time.second == 0:
            active_rides = len(self.active_rides)
            available_drivers = sum(1 for d in self.drivers.values() if d['status'] == 'AVAILABLE')
            busy_drivers = sum(1 for d in self.drivers.values() if d['status'] in ['EN_ROUTE_TO_PICKUP', 'WITH_PASSENGER'])
            
            print(f"\n[{self.current_time}] Simulation status:")
            print(f"  Active rides: {active_rides}")
            print(f"  Available drivers: {available_drivers}")
            print(f"  Busy drivers: {busy_drivers}")
            print(f"  Total requests so far: {stats['total_requests']}")
            print(f"  Completed rides: {stats['completed_rides']}")
            print(f"  Cancelled rides: {stats['cancelled_rides']}")
            print(f"  Total fare collected: ${stats['total_fare']:.2f}")
        
        # Advance time
        self.current_time += datetime.timedelta(seconds=time_step_seconds)
    
    # Calculate average wait time and ride duration
    if wait_times:
        stats['avg_wait_time'] = sum(wait_times) / len(wait_times)
    
    if ride_durations:
        stats['avg_ride_duration'] = sum(ride_durations) / len(ride_durations)
    
    # Print summary
    print("\n" + "="*50)
    print(f"Simulation completed: {start_time} to {end_time}")
    print(f"Total duration: {duration_minutes} minutes")
    print(f"Total ride requests: {stats['total_requests']}")
    print(f"Completed rides: {stats['completed_rides']}")
    print(f"Cancelled rides: {stats['cancelled_rides']}")
    print(f"Total fare collected: ${stats['total_fare']:.2f}")
    print(f"Average wait time: {stats['avg_wait_time']:.2f} minutes")
    print(f"Average ride duration: {stats['avg_ride_duration']:.2f} minutes")
    print(f"Generated {len(stats['saved_files'])} data files")
    print("="*50)
    
    return stats

# Add the method to the RideHailingDataGenerator class
RideHailingDataGenerator.run_simulation = run_simulation

# %% [markdown]
# ## Step 9: Create the main execution script

# %%
# Step 9: Create the main execution script (Jupyter Notebook version)

import json
import os
import datetime  # Import the whole module

# Configuration parameters (modify these as needed)
config = {
    'num_drivers': 1000,
    'num_users': 5000,
    'start_time': '2023-03-01 08:00:00',
    'base_request_rate': 5
}

# Simulation parameters
duration_minutes = 720  # Run for 60 minutes to see more completed rides
time_step_seconds = 60
output_dir = 'simulation_results'

# Create output directory
os.makedirs(output_dir, exist_ok=True)

# Initialize the generator
print("Initializing ride-hailing simulation...")
generator = RideHailingDataGenerator(config)

# Run the simulation
print(f"\nRunning simulation for {duration_minutes} minutes...")
stats = generator.run_simulation(
    duration_minutes=duration_minutes,
    time_step_seconds=time_step_seconds,
    verbose=True
)

# Save simulation results
results_file = os.path.join(output_dir, 'simulation_results.json')
with open(results_file, 'w') as f:
    json.dump({
        'config': config,
        'stats': {k: v for k, v in stats.items() if k != 'saved_files'},  # Remove file paths from JSON
        'timestamp': datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    }, f, indent=2)

print(f"\nSimulation results saved to {results_file}")

# Generate summary report
summary_file = os.path.join(output_dir, 'simulation_summary.txt')
with open(summary_file, 'w') as f:
    f.write("RIDE-HAILING SIMULATION SUMMARY\n")
    f.write("=" * 40 + "\n\n")
    
    f.write("Configuration:\n")
    f.write(f"  Drivers: {config['num_drivers']}\n")
    f.write(f"  Users: {config['num_users']}\n")
    f.write(f"  Start time: {config['start_time']}\n")
    f.write(f"  Base request rate: {config['base_request_rate']} per minute\n")
    f.write(f"  Duration: {duration_minutes} minutes\n\n")
    
    f.write("Results:\n")
    f.write(f"  Total ride requests: {stats['total_requests']}\n")
    f.write(f"  Completed rides: {stats['completed_rides']}\n")
    f.write(f"  Cancelled rides: {stats['cancelled_rides']}\n")
    f.write(f"  Total fare collected: ${stats['total_fare']:.2f}\n")
    f.write(f"  Average wait time: {stats['avg_wait_time']:.2f} minutes\n")
    f.write(f"  Average ride duration: {stats['avg_ride_duration']:.2f} minutes\n\n")
    
    f.write("Hourly request distribution:\n")
    for hour, count in stats['ride_requests_by_hour'].items():
        f.write(f"  {hour}: {count} requests\n")

print(f"Summary report saved to {summary_file}")

# Print final message
print("\nSimulation completed successfully!")
print(f"Generated {len(stats['saved_files'])} data files")
print(f"Processed {stats['total_requests']} ride requests")
print(f"Completed {stats['completed_rides']} rides")
print(f"Total revenue: ${stats['total_fare']:.2f}")
# Out:
# Initializing ride-hailing simulation...
# Initialized RideHailingDataGenerator with 1000 drivers and 5000 users
#
# Running simulation for 720 minutes...
# Starting simulation at 2023-03-01 08:00:00 for 720 minutes
# Initial state: 1000 drivers, 5000 users
# Generated 10 ride requests at 2023-03-01 08:00:00
# Matched driver D-da435b9f to ride R-67e25e17-246c-4909-addd-765a8017d3f9 (distance: 0.93 km)
# Matched driver D-60cd452b to ride R-da7753a9-e8fd-4558-93f3-ea550c3c6cf1 (distance: 0.12 km)
# Matched driver D-5e87bff9 to ride R-23a3cd63-f25c-4d54-9964-718d399762f2 (distance: 0.85 km)
# Matched driver D-14dac7a6 to ride R-42afe3c1-f2da-48bf-97b6-f2150b24a5c0 (distance: 0.20 km)
# Matched driver D-490e6a5e to ride R-5bcbe575-cc75-4b1f-87a2-d7d6aab45ac7 (distance: 1.50 km)
# Matched driver D-b905bd6c to ride R-274fd9f7-75f1-4411-a9db-0cff8791bc13 (distance: 0.10 km)
# Matched driver D-dd87bd2a to ride R-56493468-43fe-4a4d-b291-730619034578 (distance: 1.11 km)
# Matched driver D-17742a9a to ride R-2ec30495-ceae-485a-8f07-c36063831174 (distance: 0.22 km)
# Matched driver D-f18de60b to ride R-b6daa946-274e-4c6a-aee9-abf6d15a2060 (distance: 0.23 km)
# Matched driver D-6799bb23 to ride R-b027d221-021f-48d4-8e42-4a4436582d66 (distance: 0.29 km)
# Driver D-facaa928 came online
# Driver D-13c0943d came online
# Driver D-05518bcd came online
# Driver D-4163880e went offline
# Driver D-e509486d came online
# Driver D-ce12d68f went offline
# Driver D-bc227bbb went offline
# Driver D-fe8a8ba5 went offline
# Driver D-8ea22a68 went offline
# Driver D-32d8af07 came online
# Driver D-58af565f came online
# Driver D-7c8ec114 went offline
# Driver D-f9567620 went offline
# Saved 10 ride_requests records to data/json/ride_requests/ride_requests_20230301_080000.json
# Saved 10 ride_requests records to data/avro/ride_requests/ride_requests_20230301_080000.avro
# Saved 899 driver_status records to data/json/driver_status/driver_status_20230301_080000.json
# Saved 899 driver_status records to data/avro/driver_status/driver_status_20230301_080000.avro
#
# [2023-03-01 08:00:00] Simulation status:
#   Active rides: 10
#   Available drivers: 578
#   Busy drivers: 10
#   Total requests so far: 10
#   Completed rides: 0
#   Cancelled rides: 0
#   Total fare collected: $0.00
# Generated 11 ride requests at 2023-03-01 08:01:00
# Matched driver D-987b0ccb to ride R-cf24a866-5db1-40b5-a18c-38fdefa3b0ea (distance: 2.17 km)
# Matched driver D-69733ca6 to ride R-668b2e2b-0601-42be-a931-d82a35c9b635 (distance: 0.50 km)
# Matched driver D-a0fc85e5 to ride R-7a9a3721-e3d1-47f0-b4da-446cc606d5ff (distance: 2.67 km)
# Matched driver D-9ec14036 to ride R-6b7bd823-0be1-4a9a-8da3-2da2fa569b41 (distance: 0.21 km)
# Matched driver D-be1885ac to ride R-8302dc5d-3178-4e3f-8696-9e6297b6d432 (distance: 1.38 km)
# Matched driver D-0532e845 to ride R-2c52a20d-4dd5-40d0-9612-e04638aadc15 (distance: 0.67 km)
# Matched driver D-2e7f5a0e to ride R-4b1b795e-232a-47d9-ace4-27561091257a (distance: 0.21 km)
# Matched driver D-aae31c1a to ride R-098ceec4-0e9d-4108-9271-6689b8b2592f (distance: 2.30 km)
# Matched driver D-d29b06f1 to ride R-12cb4c70-9db5-46a5-bc16-04e35aca7f1a (distance: 1.50 km)
# Matched driver D-673ce17e to ride R-c2b72052-4bb2-4ddf-801b-7a03b91ef3b8 (distance: 0.24 km)
# Driver D-120a106a went offline
# Driver D-42ee5cd9 came online
# Driver D-3aa8309b went offline
# Driver D-cfd46df4 went offline
# Driver D-0379cd51 came online
# Driver D-91222d05 came online
# Driver D-af8a775c came online
# Driver D-bbdeea0b came online
# Driver D-3956272e came online
# Driver D-fcee3b8f came online
# Driver D-987b0ccb cancelled assignment to ride R-cf24a866-5db1-40b5-a18c-38fdefa3b0ea
# Saved 11 ride_requests records to data/json/ride_requests/ride_requests_20230301_080100.json
# Saved 11 ride_requests records to data/avro/ride_requests/ride_requests_20230301_080100.avro
# Saved 899 driver_status records to data/json/driver_status/driver_status_20230301_080100.json
# Saved 899 driver_status records to data/avro/driver_status/driver_status_20230301_080100.avro
# Generated 10 ride requests at 2023-03-01 08:02:00
# Matched driver D-987b0ccb to ride R-cf24a866-5db1-40b5-a18c-38fdefa3b0ea (distance: 2.08 km)
# Matched driver D-29a72c93 to ride R-a5fe8912-85e7-4691-bce3-ed8e07eff51e (distance: 2.97 km)
# Matched driver D-1efa6127 to ride R-8e7b26bf-e2e2-4aa9-9aef-ebfffa6950d2 (distance: 0.59 km)
# Matched driver D-23bc1346 to ride R-3a531ed3-7a15-4fb9-b5d1-7363c4ded347 (distance: 1.73 km)
# Matched driver D-78593bba to ride R-08840aff-e166-4d48-ac0c-bcfc4b18899b (distance: 0.43 km)
# Matched driver D-cfb84c22 to ride R-b6d74e17-9afb-40f3-8268-6b6b1eccd954 (distance: 0.38 km)
# Matched driver D-fe3078be to ride R-ea788ad4-3c97-4880-bba4-6e336d871b2a (distance: 0.61 km)
# Matched driver D-94d6b7d9 to ride R-2c50e694-db46-46f0-b0b8-9d5ef86da8f4 (distance: 0.73 km)
# Matched driver D-cc9bb50e to ride R-b8e181a3-9093-4deb-9f1b-22cedad429f8 (distance: 0.34 km)
# Matched driver D-538c1a30 to ride R-5f9e81d2-5202-42af-bb52-0e5336e7f75f (distance: 1.28 km)
# Driver D-60cd452b arrived at pickup for ride R-da7753a9-e8fd-4558-93f3-ea550c3c6cf1
# Driver D-79c47742 came online
# Driver D-c5ee6867 came online
# Driver D-1ee60e34 went offline
# Driver D-0a9d2976 came online
# Driver D-c504919c went offline
# Driver D-e65df3d1 came online
# Driver D-db3f6640 went offline
# Driver D-17742a9a arrived at pickup for ride R-2ec30495-ceae-485a-8f07-c36063831174
# Driver D-55008f43 came online
# Driver D-a20caf59 came online
# Driver D-370ef67e came online
# Driver D-a1075f34 went offline
# Driver D-ef08c2f6 went offline
# Driver D-e31b40b7 came online
# Driver D-b905bd6c arrived at pickup for ride R-274fd9f7-75f1-4411-a9db-0cff8791bc13
# Ride R-da7753a9-e8fd-4558-93f3-ea550c3c6cf1 started with driver D-60cd452b
# Ride R-274fd9f7-75f1-4411-a9db-0cff8791bc13 started with driver D-b905bd6c
# Ride R-2ec30495-ceae-485a-8f07-c36063831174 started with driver D-17742a9a
# Saved 10 ride_requests records to data/json/ride_requests/ride_requests_20230301_080200.json
# Saved 10 ride_requests records to data/avro/ride_requests/ride_requests_20230301_080200.avro
# Saved 904 driver_status records to data/json/driver_status/driver_status_20230301_080200.json
# Saved 904 driver_status records to data/avro/driver_status/driver_status_20230301_080200.avro
# Generated 17 ride requests at 2023-03-01 08:03:00
# Matched driver D-f0b48bfb to ride R-3eba8661-00ca-40f7-b631-ca6aa133137a (distance: 0.13 km)
# Matched driver D-661f7e9a to ride R-8ac67ef0-474b-4b83-99ce-78f402c946c4 (distance: 0.42 km)
# Matched driver D-c78c2526 to ride R-bc831194-1e87-4241-a98c-0ca6693118fa (distance: 0.21 km)
# Matched driver D-0c7491e0 to ride R-c76d8148-4c01-4aaa-8a6c-391695c8d8e1 (distance: 0.54 km)
# Matched driver D-7cf8afa8 to ride R-8f4fbc21-1b7b-4a0e-98ad-f34e0d9d697d (distance: 0.03 km)
# Matched driver D-9774104e to ride R-c22b311b-1363-49f0-b034-219f07945e14 (distance: 0.40 km)
# Matched driver D-0bf3a4b7 to ride R-1ca5aba6-3ce3-4184-8425-9442806b9945 (distance: 0.85 km)
# Matched driver D-a8a46b48 to ride R-9717674a-96cf-4680-bddc-bdd5e8309b97 (distance: 2.29 km)
# Matched driver D-f5715426 to ride R-723103ef-6b5a-4124-9088-a161d1d7d25b (distance: 0.73 km)
# Matched driver D-abf16b19 to ride R-2d822775-b101-45a0-9e50-16b4f3393993 (distance: 0.24 km)
# Matched driver D-919986b4 to ride R-65cac898-7579-4615-af42-bdea4345bc8b (distance: 0.30 km)
# Matched driver D-bf1ab677 to ride R-29504de1-abf3-4a8c-9470-80b7bf580580 (distance: 0.10 km)
# Matched driver D-341493df to ride R-3c637491-ff0e-45dd-a0fd-e0b308ea0447 (distance: 0.09 km)
# Matched driver D-f43a5fca to ride R-9dddae35-3872-48b1-ab09-869fbeb2b851 (distance: 1.12 km)
# Matched driver D-646a4fb7 to ride R-c327fff7-5646-46b9-9b25-6b7d954fdab0 (distance: 0.11 km)
# Matched driver D-f071193f to ride R-90315574-9244-457e-a864-35c0ea6295b4 (distance: 0.34 km)
# Driver D-db3f6640 came online
# Driver D-14dac7a6 arrived at pickup for ride R-42afe3c1-f2da-48bf-97b6-f2150b24a5c0
# Driver D-650ef016 went offline
# Driver D-f18de60b arrived at pickup for ride R-b6daa946-274e-4c6a-aee9-abf6d15a2060
# Driver D-a6f8eccf came online
# Driver D-91222d05 went offline
# Driver D-6799bb23 arrived at pickup for ride R-b027d221-021f-48d4-8e42-4a4436582d66
# Driver D-e93be07b went offline
# Driver D-32d8af07 went offline
# Driver D-cb8ac27c went offline
# Driver D-1075c3cb came online
# Ride R-42afe3c1-f2da-48bf-97b6-f2150b24a5c0 started with driver D-14dac7a6
# Ride R-b6daa946-274e-4c6a-aee9-abf6d15a2060 started with driver D-f18de60b
# Ride R-b027d221-021f-48d4-8e42-4a4436582d66 started with driver D-6799bb23
# Driver D-bf1ab677 cancelled assignment to ride R-29504de1-abf3-4a8c-9470-80b7bf580580
# Saved 17 ride_requests records to data/json/ride_requests/ride_requests_20230301_080300.json
# Saved 17 ride_requests records to data/avro/ride_requests/ride_requests_20230301_080300.avro
# Saved 902 driver_status records to data/json/driver_status/driver_status_20230301_080300.json
# Saved 902 driver_status records to data/avro/driver_status/driver_status_20230301_080300.avro
# Generated 7 ride requests at 2023-03-01 08:04:00
# Matched driver D-bf1ab677 to ride R-29504de1-abf3-4a8c-9470-80b7bf580580 (distance: 0.01 km)
# Matched driver D-21e9275b to ride R-7bddcd6c-96b5-412e-87bd-b56a2818a9ce (distance: 0.20 km)
# Matched driver D-2096ccc5 to ride R-866917e3-7568-4849-b862-b2aba34678c5 (distance: 0.56 km)
# Matched driver D-b8432550 to ride R-6226f080-a7dc-48c8-bae4-a6aa789ec445 (distance: 1.63 km)
# Matched driver D-9f5f1c79 to ride R-90874fd7-da11-4021-981f-c24cea4d028b (distance: 0.15 km)
# Matched driver D-df5d7edb to ride R-1922b476-115d-45d4-ab1f-a9ad93f28954 (distance: 0.14 km)
# Matched driver D-0a9d2976 to ride R-b40f6993-7ca7-4641-8693-8a2dfdca9618 (distance: 0.20 km)
# Matched driver D-82b95926 to ride R-9d244217-102e-4cfc-9def-67540a5c4362 (distance: 0.43 km)
# Driver D-341493df arrived at pickup for ride R-3c637491-ff0e-45dd-a0fd-e0b308ea0447
# Driver D-b1cb35b6 came online
# Driver D-1ee60e34 came online
# Driver D-7cf8afa8 arrived at pickup for ride R-8f4fbc21-1b7b-4a0e-98ad-f34e0d9d697d
# Driver D-646a4fb7 arrived at pickup for ride R-c327fff7-5646-46b9-9b25-6b7d954fdab0
# Driver D-e7d1a819 came online
# Driver D-cb31942c went offline
# Driver D-bf1ab677 arrived at pickup for ride R-29504de1-abf3-4a8c-9470-80b7bf580580
# Driver D-673ce17e arrived at pickup for ride R-c2b72052-4bb2-4ddf-801b-7a03b91ef3b8
# Driver D-a222a43d came online
# Driver D-2e7f5a0e arrived at pickup for ride R-4b1b795e-232a-47d9-ace4-27561091257a
# Driver D-d39b3c62 went offline
# Driver D-9ec14036 arrived at pickup for ride R-6b7bd823-0be1-4a9a-8da3-2da2fa569b41
# Ride R-6b7bd823-0be1-4a9a-8da3-2da2fa569b41 started with driver D-9ec14036
# Ride R-4b1b795e-232a-47d9-ace4-27561091257a started with driver D-2e7f5a0e
# Ride R-c2b72052-4bb2-4ddf-801b-7a03b91ef3b8 started with driver D-673ce17e
# Ride R-8f4fbc21-1b7b-4a0e-98ad-f34e0d9d697d started with driver D-7cf8afa8
# User U-49f426e1 no-show for ride R-29504de1-abf3-4a8c-9470-80b7bf580580
# Ride R-3c637491-ff0e-45dd-a0fd-e0b308ea0447 started with driver D-341493df
# Ride R-c327fff7-5646-46b9-9b25-6b7d954fdab0 started with driver D-646a4fb7
# Saved 7 ride_requests records to data/json/ride_requests/ride_requests_20230301_080400.json
# Saved 7 ride_requests records to data/avro/ride_requests/ride_requests_20230301_080400.avro
# Saved 901 driver_status records to data/json/driver_status/driver_status_20230301_080400.json
# Saved 901 driver_status records to data/avro/driver_status/driver_status_20230301_080400.avro
# Bad weather at 2023-03-01 08:05:00! Demand multiplier: 1.46
# Generated 15 ride requests at 2023-03-01 08:05:00
# Matched driver D-cc801701 to ride R-541623d3-ff1a-4ef7-a815-d05b2ab7efe3 (distance: 0.97 km)
# Matched driver D-29f20462 to ride R-70565a98-004e-4f4b-a2a1-cb997418d63b (distance: 2.45 km)
# Matched driver D-7329b86d to ride R-878a7774-8a01-474f-834d-3d183e3c90d7 (distance: 0.96 km)
# Matched driver D-3a83929a to ride R-3df0de58-5290-4360-9a66-d1d4b3666115 (distance: 0.30 km)
# Matched driver D-ecdadd1b to ride R-d3e3cecc-9148-463a-8269-638a5695d877 (distance: 2.62 km)
# Matched driver D-9132f295 to ride R-b3ff58cb-7608-4a89-84d2-28b0ec0a5a44 (distance: 0.35 km)
# Matched driver D-57b61a85 to ride R-6cf2a93c-bbfe-4b97-834f-52defb3a27bc (distance: 0.18 km)
# Matched driver D-e5a461a5 to ride R-5ff89de3-00a1-48cd-8ed5-3e49ab9eec53 (distance: 0.38 km)
# Matched driver D-c96b452f to ride R-a1bc67d6-099c-4ff0-aacb-93a34f4face3 (distance: 0.28 km)
# Matched driver D-f4d93850 to ride R-8831a61f-875b-42cf-ae9d-e901f7f3efb5 (distance: 0.35 km)
# Matched driver D-6667ec7c to ride R-284dae27-97cb-49a4-8107-dfda33990a2d (distance: 1.67 km)
# Matched driver D-ad7a04c3 to ride R-5302c252-f0d7-4422-9668-be541b79149f (distance: 0.30 km)
# Matched driver D-2a79fab5 to ride R-c094c6a3-bcd2-4970-a0ac-c464eb1ebdd1 (distance: 0.57 km)
# Driver D-c78c2526 arrived at pickup for ride R-bc831194-1e87-4241-a98c-0ca6693118fa
# Driver D-29ee482f went offline
# Driver D-4e65bf52 went offline
# Driver D-f0936f29 went offline
# Driver D-32d8af07 came online
# Driver D-0478e8b4 came online
# Driver D-f0b48bfb arrived at pickup for ride R-3eba8661-00ca-40f7-b631-ca6aa133137a
# Driver D-6ccce5be went offline
# Driver D-c196a1a1 went offline
# Driver D-808b618c went offline
# User U-44b81780 cancelled ride R-3ef29cc6-ee9e-4e83-9458-941e748bfa05 after waiting 3.0 minutes
# Ride R-3eba8661-00ca-40f7-b631-ca6aa133137a started with driver D-f0b48bfb
# Ride R-bc831194-1e87-4241-a98c-0ca6693118fa started with driver D-c78c2526
# User U-30057a31 cancelled ride R-e5705b2f-d770-4c2a-b965-bb18edd5b50f after waiting 0.0 minutes
# Saved 15 ride_requests records to data/json/ride_requests/ride_requests_20230301_080500.json
# Saved 15 ride_requests records to data/avro/ride_requests/ride_requests_20230301_080500.avro
# Saved 901 driver_status records to data/json/driver_status/driver_status_20230301_080500.json
# Saved 901 driver_status records to data/avro/driver_status/driver_status_20230301_080500.avro
#
# [2023-03-01 08:05:00] Simulation status:
#   Active rides: 67
#   Available drivers: 527
#   Busy drivers: 64
#   Total requests so far: 70
#   Completed rides: 0
#   Cancelled rides: 3
#   Total fare collected: $0.00
# Special event occurring at 2023-03-01 08:06:00! Demand multiplier: 2.60
# Generated 30 ride requests at 2023-03-01 08:06:00
# Matched driver D-dd10d56c to ride R-eb0d8800-97b2-41ec-90cb-b7c9b271658a (distance: 0.41 km)
# Matched driver D-a38162e0 to ride R-052d6cf1-dbc2-4dd7-ba09-775f0702bf2f (distance: 0.05 km)
# Matched driver D-3b624477 to ride R-81695db4-c808-406c-9b4b-b5a5543b4b15 (distance: 0.29 km)
# Matched driver D-bf7f015a to ride R-1d5376d0-d486-4f2d-9980-210b669cef9f (distance: 0.32 km)
# Matched driver D-c9fab969 to ride R-7774d943-b3d8-4935-884e-2c368fd42545 (distance: 0.75 km)
# Matched driver D-5001746e to ride R-cf0bc529-09e8-4391-8db8-46915f16995f (distance: 0.55 km)
# Matched driver D-3d11ff27 to ride R-85933f76-e4c7-4d4b-a0f1-92c9a0dc3ec1 (distance: 0.04 km)
# Matched driver D-e152e748 to ride R-5d973b1a-c489-4c76-b29a-8f0653b5f36b (distance: 0.23 km)
# Matched driver D-fb4f677e to ride R-f5abab8d-6c43-41eb-ba5f-808ed2327805 (distance: 0.15 km)
# Matched driver D-fc1c773f to ride R-3b39e8d3-8b7b-4097-af5d-2ba2bd29ab7b (distance: 1.36 km)
# Matched driver D-7dbe1413 to ride R-f67cefdc-0fd1-4b0d-b117-99ee4a20ff5e (distance: 0.35 km)
# Matched driver D-97db4b2b to ride R-4f92427b-272d-41e5-97a1-d789cb6440d7 (distance: 0.34 km)
# Matched driver D-3ef6b79e to ride R-8ba5b137-c527-440b-88c1-f7af85fa26fb (distance: 0.16 km)
# Matched driver D-d83f8cd3 to ride R-0a6d029c-2d2c-4aaa-9776-a2ff3450d6de (distance: 0.75 km)
# Matched driver D-d942cc57 to ride R-adf9d00a-6d18-41fe-b99b-d685718dab3c (distance: 0.16 km)
# Matched driver D-8b858184 to ride R-9ffc4749-8fc6-466a-bf11-87b78d2c87b8 (distance: 0.27 km)
# Matched driver D-b83e0ce2 to ride R-2619d166-45b9-4c59-83c0-2f4a9fea29f0 (distance: 2.59 km)
# Matched driver D-3553c07a to ride R-06a84fc9-10f9-4d51-9974-b039911a8e75 (distance: 0.23 km)
# Matched driver D-f407499c to ride R-3bca5a65-eb63-4b55-b783-0f41a3095c78 (distance: 0.13 km)
# Matched driver D-88899400 to ride R-5ef0d775-e084-49da-9108-28c80827c86f (distance: 0.31 km)
# Driver D-8e93d76c went offline
# Driver D-47cd1b9a went offline
# Driver D-df5d7edb arrived at pickup for ride R-1922b476-115d-45d4-ab1f-a9ad93f28954
# Driver D-cfb84c22 arrived at pickup for ride R-b6d74e17-9afb-40f3-8268-6b6b1eccd954
# Driver D-0b0eb8ed came online
# Driver D-f40a021c came online
# Driver D-0fe92731 went offline
# Driver D-586d60b3 came online
# Driver D-abf16b19 arrived at pickup for ride R-2d822775-b101-45a0-9e50-16b4f3393993
# Driver D-f98af949 came online
# Driver D-cc9bb50e arrived at pickup for ride R-b8e181a3-9093-4deb-9f1b-22cedad429f8
# Driver D-9f5f1c79 arrived at pickup for ride R-90874fd7-da11-4021-981f-c24cea4d028b
# Driver D-0532e845 cancelled assignment to ride R-2c52a20d-4dd5-40d0-9612-e04638aadc15
# Ride R-b6d74e17-9afb-40f3-8268-6b6b1eccd954 started with driver D-cfb84c22
# Ride R-b8e181a3-9093-4deb-9f1b-22cedad429f8 started with driver D-cc9bb50e
# Ride R-2d822775-b101-45a0-9e50-16b4f3393993 started with driver D-abf16b19
# Ride R-90874fd7-da11-4021-981f-c24cea4d028b started with driver D-9f5f1c79
# Ride R-1922b476-115d-45d4-ab1f-a9ad93f28954 started with driver D-df5d7edb
# Driver D-cc801701 cancelled assignment to ride R-541623d3-ff1a-4ef7-a815-d05b2ab7efe3
# Saved 30 ride_requests records to data/json/ride_requests/ride_requests_20230301_080600.json
# Saved 30 ride_requests records to data/avro/ride_requests/ride_requests_20230301_080600.avro
# Saved 899 driver_status records to data/json/driver_status/driver_status_20230301_080600.json
# Saved 899 driver_status records to data/avro/driver_status/driver_status_20230301_080600.avro
# Generated 9 ride requests at 2023-03-01 08:07:00
# Matched driver D-0532e845 to ride R-2c52a20d-4dd5-40d0-9612-e04638aadc15 (distance: 0.04 km)
# Matched driver D-cc801701 to ride R-541623d3-ff1a-4ef7-a815-d05b2ab7efe3 (distance: 0.80 km)
# Matched driver D-55e197b9 to ride R-c4032c59-23ed-4e23-b785-af5a0bd307da (distance: 0.05 km)
# Matched driver D-8ce3115a to ride R-14e19e23-298c-4e38-9a3b-7595f443c2b4 (distance: 1.10 km)
# Matched driver D-da087a68 to ride R-d9e6fdc4-509a-4e77-94ab-667f26b0c5ae (distance: 0.24 km)
# Matched driver D-0b0eb8ed to ride R-5396ab3a-dbd8-4c3a-8e6e-45b6c65809c2 (distance: 2.80 km)
# Matched driver D-f8f5cc14 to ride R-d57bd4f6-9f78-4bfd-910f-8f1c3b9a3c16 (distance: 0.43 km)
# Matched driver D-934c4eea to ride R-986c0eda-127c-48ce-8eba-0e956de8030a (distance: 0.56 km)
# Matched driver D-54e48267 to ride R-7a689553-8ea8-4c7d-a026-fc9ce0f347a5 (distance: 0.35 km)
# Driver D-f8d69f09 went offline
# Driver D-5ef69800 came online
# Driver D-154d0ae7 went offline
# Driver D-661f7e9a arrived at pickup for ride R-8ac67ef0-474b-4b83-99ce-78f402c946c4
# Driver D-b3606513 came online
# Driver D-0a9d2976 arrived at pickup for ride R-b40f6993-7ca7-4641-8693-8a2dfdca9618
# Driver D-4e65bf52 came online
# Driver D-ad8991df went offline
# Driver D-7c1293cd went offline
# Driver D-bd84d09d came online
# Driver D-9774104e arrived at pickup for ride R-c22b311b-1363-49f0-b034-219f07945e14
# Driver D-57b61a85 arrived at pickup for ride R-6cf2a93c-bbfe-4b97-834f-52defb3a27bc
# Driver D-21e9275b arrived at pickup for ride R-7bddcd6c-96b5-412e-87bd-b56a2818a9ce
# Driver D-45b85a21 went offline
# Driver D-b67666c0 went offline
# Driver D-919986b4 arrived at pickup for ride R-65cac898-7579-4615-af42-bdea4345bc8b
# Driver D-78593bba arrived at pickup for ride R-08840aff-e166-4d48-ac0c-bcfc4b18899b
# Driver D-3d11ff27 arrived at pickup for ride R-85933f76-e4c7-4d4b-a0f1-92c9a0dc3ec1
# Driver D-e93be07b came online
# Driver D-402f866a came online
# Driver D-6e584d30 went offline
# Driver D-0478e8b4 went offline
# Driver D-a38162e0 arrived at pickup for ride R-052d6cf1-dbc2-4dd7-ba09-775f0702bf2f
# Driver D-69733ca6 arrived at pickup for ride R-668b2e2b-0601-42be-a931-d82a35c9b635
# Driver D-f071193f arrived at pickup for ride R-90315574-9244-457e-a864-35c0ea6295b4
# Driver D-86bd5f37 went offline
# Driver D-7b2e26cb came online
# Ride R-668b2e2b-0601-42be-a931-d82a35c9b635 started with driver D-69733ca6
# Ride R-08840aff-e166-4d48-ac0c-bcfc4b18899b started with driver D-78593bba
# Ride R-8ac67ef0-474b-4b83-99ce-78f402c946c4 started with driver D-661f7e9a
# Ride R-c22b311b-1363-49f0-b034-219f07945e14 started with driver D-9774104e
# Ride R-65cac898-7579-4615-af42-bdea4345bc8b started with driver D-919986b4
# Ride R-90315574-9244-457e-a864-35c0ea6295b4 started with driver D-f071193f
# Ride R-7bddcd6c-96b5-412e-87bd-b56a2818a9ce started with driver D-21e9275b
# Ride R-b40f6993-7ca7-4641-8693-8a2dfdca9618 started with driver D-0a9d2976
# Ride R-6cf2a93c-bbfe-4b97-834f-52defb3a27bc started with driver D-57b61a85
# Ride R-052d6cf1-dbc2-4dd7-ba09-775f0702bf2f started with driver D-a38162e0
# Ride R-85933f76-e4c7-4d4b-a0f1-92c9a0dc3ec1 started with driver D-3d11ff27
# User U-512f4db6 cancelled ride R-d4fe732b-7cd4-4a0e-a871-47bab9869ea5 after waiting 1.0 minutes
# Saved 9 ride_requests records to data/json/ride_requests/ride_requests_20230301_080700.json
# Saved 9 ride_requests records to data/avro/ride_requests/ride_requests_20230301_080700.avro
# Saved 903 driver_status records to data/json/driver_status/driver_status_20230301_080700.json
# Saved 903 driver_status records to data/avro/driver_status/driver_status_20230301_080700.avro
# Generated 9 ride requests at 2023-03-01 08:08:00
# Matched driver D-bd84d09d to ride R-1b5d997e-3f64-4aa2-8589-682bca88a6b4 (distance: 2.29 km)
# Matched driver D-702280b8 to ride R-316637a8-a636-4fb5-a5ee-ccf6b75d691b (distance: 0.32 km)
# Matched driver D-b3eaabc2 to ride R-a473af1a-d321-4a1d-acd9-e70aa307af92 (distance: 0.80 km)
# Matched driver D-abfa5143 to ride R-bbe749fb-831b-4ffd-9313-1080245bf7b2 (distance: 0.40 km)
# Matched driver D-15e84e89 to ride R-e670bb87-89a7-429a-8c30-bfc2c5694d67 (distance: 0.40 km)
# Matched driver D-29835c06 to ride R-20030f2c-09d3-4200-81f5-171a001afc0f (distance: 1.86 km)
# Matched driver D-1524ace1 to ride R-7eb3a5a4-4d72-4d50-9112-1a212714a882 (distance: 0.21 km)
# Driver D-fc095763 came online
# Driver D-f8d69f09 came online
# Driver D-0532e845 arrived at pickup for ride R-2c52a20d-4dd5-40d0-9612-e04638aadc15
# Driver D-d942cc57 arrived at pickup for ride R-adf9d00a-6d18-41fe-b99b-d685718dab3c
# Driver D-1efa6127 arrived at pickup for ride R-8e7b26bf-e2e2-4aa9-9aef-ebfffa6950d2
# Driver D-f407499c arrived at pickup for ride R-3bca5a65-eb63-4b55-b783-0f41a3095c78
# Driver D-ad7a04c3 arrived at pickup for ride R-5302c252-f0d7-4422-9668-be541b79149f
# Driver D-55e197b9 arrived at pickup for ride R-c4032c59-23ed-4e23-b785-af5a0bd307da
# Driver D-3553c07a arrived at pickup for ride R-06a84fc9-10f9-4d51-9974-b039911a8e75
# Driver D-3ef6b79e arrived at pickup for ride R-8ba5b137-c527-440b-88c1-f7af85fa26fb
# Driver D-d440ff4e came online
# Driver D-1ab65f64 came online
# Driver D-0478e8b4 came online
# Driver D-69add3b6 came online
# Driver D-86bd5f37 came online
# Driver D-fb4f677e arrived at pickup for ride R-f5abab8d-6c43-41eb-ba5f-808ed2327805
# User U-37706e92 cancelled ride R-88316fb7-34f4-44a2-bc7f-a7a7f56221a7 after waiting 7.0 minutes
# Ride R-2c52a20d-4dd5-40d0-9612-e04638aadc15 started with driver D-0532e845
# Ride R-8e7b26bf-e2e2-4aa9-9aef-ebfffa6950d2 started with driver D-1efa6127
# Driver D-538c1a30 cancelled assignment to ride R-5f9e81d2-5202-42af-bb52-0e5336e7f75f
# Driver D-2096ccc5 cancelled assignment to ride R-866917e3-7568-4849-b862-b2aba34678c5
# Ride R-5302c252-f0d7-4422-9668-be541b79149f started with driver D-ad7a04c3
# Ride R-f5abab8d-6c43-41eb-ba5f-808ed2327805 started with driver D-fb4f677e
# Ride R-8ba5b137-c527-440b-88c1-f7af85fa26fb started with driver D-3ef6b79e
# Ride R-adf9d00a-6d18-41fe-b99b-d685718dab3c started with driver D-d942cc57
# Ride R-06a84fc9-10f9-4d51-9974-b039911a8e75 started with driver D-3553c07a
# Ride R-3bca5a65-eb63-4b55-b783-0f41a3095c78 started with driver D-f407499c
# Ride R-c4032c59-23ed-4e23-b785-af5a0bd307da started with driver D-55e197b9
# User U-4e18ed66 cancelled ride R-cdcac42e-5430-42e9-b7e5-dcaf2a852a7e after waiting 1.0 minutes
# Saved 9 ride_requests records to data/json/ride_requests/ride_requests_20230301_080800.json
# Saved 9 ride_requests records to data/avro/ride_requests/ride_requests_20230301_080800.avro
# Saved 901 driver_status records to data/json/driver_status/driver_status_20230301_080800.json
# Saved 901 driver_status records to data/avro/driver_status/driver_status_20230301_080800.avro
# Generated 12 ride requests at 2023-03-01 08:09:00
# Matched driver D-538c1a30 to ride R-5f9e81d2-5202-42af-bb52-0e5336e7f75f (distance: 0.51 km)
# Matched driver D-2096ccc5 to ride R-866917e3-7568-4849-b862-b2aba34678c5 (distance: 0.13 km)
# Matched driver D-f790f063 to ride R-90f58fee-70b5-4c70-b2d2-b3a33f6ae1d6 (distance: 2.00 km)
# Matched driver D-1c98674c to ride R-a65c0daa-7809-4a7f-a1fd-f0324ee79ef6 (distance: 0.11 km)
# Matched driver D-94c52f42 to ride R-64dec9f9-9824-43af-aea1-0dadc7b8663f (distance: 0.20 km)
# Matched driver D-f8d69f09 to ride R-b215d13a-a9e8-4e6c-89a7-71c080de755b (distance: 1.37 km)
# Matched driver D-c0d314c1 to ride R-17305838-e67d-4965-9bb8-17549b3fcc1f (distance: 0.74 km)
# Matched driver D-1b2ed87c to ride R-e65adf2e-19fc-4e59-b911-edc51fca1892 (distance: 3.53 km)
# Matched driver D-eb823f2b to ride R-7b957240-9982-4b90-99e4-4c9281557d26 (distance: 0.24 km)
# Matched driver D-36bc3ec1 to ride R-92f2d795-cf6d-4c8b-9788-5c9bd3b67bee (distance: 0.27 km)
# Matched driver D-5354cd95 to ride R-12138352-c0b0-461e-bf83-4f988fc98e4d (distance: 0.28 km)
# Matched driver D-051cc1c7 to ride R-ef2b17e4-6e1e-4ca6-899f-3d7a16ea6157 (distance: 1.78 km)
# Matched driver D-57efb46b to ride R-e43c6336-ce71-4f35-a901-0971f4255594 (distance: 1.26 km)
# Matched driver D-751b11e7 to ride R-edd1db58-f6e2-48f8-8e97-8edf5ead28ba (distance: 0.35 km)
# Driver D-9132f295 arrived at pickup for ride R-b3ff58cb-7608-4a89-84d2-28b0ec0a5a44
# Driver D-c96b452f arrived at pickup for ride R-a1bc67d6-099c-4ff0-aacb-93a34f4face3
# Driver D-ebaa7b6c came online
# Driver D-88899400 arrived at pickup for ride R-5ef0d775-e084-49da-9108-28c80827c86f
# Driver D-9b74b2d6 went offline
# Driver D-e152e748 arrived at pickup for ride R-5d973b1a-c489-4c76-b29a-8f0653b5f36b
# Driver D-c91f41a6 came online
# Driver D-91222d05 came online
# Driver D-3a83929a arrived at pickup for ride R-3df0de58-5290-4360-9a66-d1d4b3666115
# Driver D-f4d93850 arrived at pickup for ride R-8831a61f-875b-42cf-ae9d-e901f7f3efb5
# Driver D-252c2568 went offline
# Driver D-82b95926 arrived at pickup for ride R-9d244217-102e-4cfc-9def-67540a5c4362
# Driver D-b51c6961 went offline
# Driver D-5e87bff9 arrived at pickup for ride R-23a3cd63-f25c-4d54-9964-718d399762f2
# Driver D-e5a461a5 arrived at pickup for ride R-5ff89de3-00a1-48cd-8ed5-3e49ab9eec53
# Driver D-8b858184 arrived at pickup for ride R-9ffc4749-8fc6-466a-bf11-87b78d2c87b8
# Driver D-b4728700 went offline
# Ride R-23a3cd63-f25c-4d54-9964-718d399762f2 started with driver D-5e87bff9
# Ride R-9d244217-102e-4cfc-9def-67540a5c4362 started with driver D-82b95926
# Driver D-7329b86d cancelled assignment to ride R-878a7774-8a01-474f-834d-3d183e3c90d7
# Ride R-3df0de58-5290-4360-9a66-d1d4b3666115 started with driver D-3a83929a
# Ride R-b3ff58cb-7608-4a89-84d2-28b0ec0a5a44 started with driver D-9132f295
# Ride R-5ff89de3-00a1-48cd-8ed5-3e49ab9eec53 started with driver D-e5a461a5
# Ride R-a1bc67d6-099c-4ff0-aacb-93a34f4face3 started with driver D-c96b452f
# Ride R-8831a61f-875b-42cf-ae9d-e901f7f3efb5 started with driver D-f4d93850
# Ride R-5d973b1a-c489-4c76-b29a-8f0653b5f36b started with driver D-e152e748
# User U-0e91e640 no-show for ride R-9ffc4749-8fc6-466a-bf11-87b78d2c87b8
# Ride R-5ef0d775-e084-49da-9108-28c80827c86f started with driver D-88899400
# Saved 12 ride_requests records to data/json/ride_requests/ride_requests_20230301_080900.json
# Saved 12 ride_requests records to data/avro/ride_requests/ride_requests_20230301_080900.avro
# Saved 904 driver_status records to data/json/driver_status/driver_status_20230301_080900.json
# Saved 904 driver_status records to data/avro/driver_status/driver_status_20230301_080900.avro
# Generated 8 ride requests at 2023-03-01 08:10:00
# Matched driver D-7329b86d to ride R-878a7774-8a01-474f-834d-3d183e3c90d7 (distance: 0.48 km)
# Matched driver D-773edcb9 to ride R-dccded33-aed2-4cef-8d24-47d0eaa7030b (distance: 2.57 km)
# Matched driver D-7e827e6b to ride R-222b134b-1e29-4f53-862c-a9622eaffc3c (distance: 0.59 km)
# Matched driver D-c2cf6174 to ride R-9a36c60d-5357-4ea0-822f-562418c51064 (distance: 0.52 km)
# Matched driver D-9b8a2045 to ride R-48efb6d7-e046-418f-8ee0-53c4b33cc63d (distance: 0.13 km)
# Matched driver D-42ee5cd9 to ride R-6322533e-1a6b-4f4b-97f7-f0a010415862 (distance: 0.31 km)
# Matched driver D-ec526bca to ride R-14bf1bbd-e353-4b74-b625-b73d7023de6c (distance: 0.78 km)
# Matched driver D-d353a9d1 to ride R-97f09cb6-4044-4d92-bcb5-b7ad5605e73f (distance: 1.19 km)
# Driver D-bf7f015a arrived at pickup for ride R-1d5376d0-d486-4f2d-9980-210b669cef9f
# Driver D-7dbe1413 arrived at pickup for ride R-f67cefdc-0fd1-4b0d-b117-99ee4a20ff5e
# Driver D-5ea9aa8e came online
# Driver D-da087a68 arrived at pickup for ride R-d9e6fdc4-509a-4e77-94ab-667f26b0c5ae
# Driver D-e5a2d153 went offline
# Driver D-0c7491e0 arrived at pickup for ride R-c76d8148-4c01-4aaa-8a6c-391695c8d8e1
# Driver D-66ee2189 came online
# Driver D-cc7dfe50 came online
# Driver D-3aa8309b came online
# Driver D-50c23076 came online
# Driver D-3b624477 arrived at pickup for ride R-81695db4-c808-406c-9b4b-b5a5543b4b15
# Driver D-cfd46df4 came online
# Driver D-97db4b2b arrived at pickup for ride R-4f92427b-272d-41e5-97a1-d789cb6440d7
# Driver D-dd10d56c arrived at pickup for ride R-eb0d8800-97b2-41ec-90cb-b7c9b271658a
# Driver D-fe3078be arrived at pickup for ride R-ea788ad4-3c97-4880-bba4-6e336d871b2a
# Driver D-10a9a8d2 came online
# Driver D-1c98674c arrived at pickup for ride R-a65c0daa-7809-4a7f-a1fd-f0324ee79ef6
# Driver D-a1075f34 came online
# Driver D-909d4018 went offline
# Driver D-e75f43a3 went offline
# Driver D-1524ace1 arrived at pickup for ride R-7eb3a5a4-4d72-4d50-9112-1a212714a882
# Ride R-ea788ad4-3c97-4880-bba4-6e336d871b2a started with driver D-fe3078be
# Ride R-c76d8148-4c01-4aaa-8a6c-391695c8d8e1 started with driver D-0c7491e0
# User U-d575016e no-show for ride R-eb0d8800-97b2-41ec-90cb-b7c9b271658a
# Ride R-81695db4-c808-406c-9b4b-b5a5543b4b15 started with driver D-3b624477
# Ride R-1d5376d0-d486-4f2d-9980-210b669cef9f started with driver D-bf7f015a
# Driver D-5001746e cancelled assignment to ride R-cf0bc529-09e8-4391-8db8-46915f16995f
# Ride R-f67cefdc-0fd1-4b0d-b117-99ee4a20ff5e started with driver D-7dbe1413
# Ride R-4f92427b-272d-41e5-97a1-d789cb6440d7 started with driver D-97db4b2b
# User U-94fb2808 cancelled ride R-15109344-482e-4d91-8a59-9ee4bdb20ad6 after waiting 4.0 minutes
# Ride R-d9e6fdc4-509a-4e77-94ab-667f26b0c5ae started with driver D-da087a68
# Ride R-7eb3a5a4-4d72-4d50-9112-1a212714a882 started with driver D-1524ace1
# Ride R-a65c0daa-7809-4a7f-a1fd-f0324ee79ef6 started with driver D-1c98674c
# Saved 8 ride_requests records to data/json/ride_requests/ride_requests_20230301_081000.json
# Saved 8 ride_requests records to data/avro/ride_requests/ride_requests_20230301_081000.avro
# Saved 908 driver_status records to data/json/driver_status/driver_status_20230301_081000.json
# Saved 908 driver_status records to data/avro/driver_status/driver_status_20230301_081000.avro
#
# [2023-03-01 08:10:00] Simulation status:
#   Active rides: 129
#   Available drivers: 487
#   Busy drivers: 114
#   Total requests so far: 138
#   Completed rides: 0
#   Cancelled rides: 9
#   Total fare collected: $0.00
# Generated 9 ride requests at 2023-03-01 08:11:00
# Matched driver D-5001746e to ride R-cf0bc529-09e8-4391-8db8-46915f16995f (distance: 0.12 km)
# Matched driver D-228fab64 to ride R-167639e0-6ac7-4110-91b3-5392af93a917 (distance: 0.88 km)
# Matched driver D-e37d9a47 to ride R-902fee05-07eb-4fb4-b758-8a74dc2d72a9 (distance: 0.99 km)
# Matched driver D-91222d05 to ride R-ada09093-ddca-4011-a997-c4cdb9048eb0 (distance: 0.16 km)
# Matched driver D-34ee6db0 to ride R-d91d4717-8ec5-4fc7-b3e2-fdbb493600f5 (distance: 3.80 km)
# Matched driver D-710c240a to ride R-ca0c47e2-1251-465a-8402-db72cabd6d97 (distance: 1.06 km)
# Matched driver D-46c7c178 to ride R-78aeb70e-fd3d-47d0-8ce1-4de4cae856da (distance: 3.24 km)
# Matched driver D-b32d083d to ride R-100c3d28-08b8-41d8-82ce-593740099b8b (distance: 0.24 km)
# Matched driver D-7ae96cb1 to ride R-f8226b60-d698-424d-8952-d8dc7597643c (distance: 3.27 km)
# Matched driver D-fe71f0b5 to ride R-96da8164-ce66-410f-acd5-e1eb438c3ebc (distance: 0.69 km)
# Driver D-120a106a came online
# Driver D-2096ccc5 arrived at pickup for ride R-866917e3-7568-4849-b862-b2aba34678c5
# Driver D-f5715426 arrived at pickup for ride R-723103ef-6b5a-4124-9088-a161d1d7d25b
# Driver D-cc3c40f8 went offline
# Driver D-0fe92731 came online
# Driver D-94c52f42 arrived at pickup for ride R-64dec9f9-9824-43af-aea1-0dadc7b8663f
# Driver D-0e0512cd went offline
# Driver D-da435b9f arrived at pickup for ride R-67e25e17-246c-4909-addd-765a8017d3f9
# Driver D-aeeba391 went offline
# Driver D-87cf891d went offline
# Driver D-94d6b7d9 arrived at pickup for ride R-2c50e694-db46-46f0-b0b8-9d5ef86da8f4
# Driver D-6ccce5be came online
# Driver D-ef08c2f6 came online
# Driver D-fcee3b8f went offline
# Driver D-2e7f5a0e completed ride R-4b1b795e-232a-47d9-ace4-27561091257a
# Driver D-9974f98a came online
# Driver D-7c8ec114 came online
# Ride R-67e25e17-246c-4909-addd-765a8017d3f9 started with driver D-da435b9f
# Ride R-4b1b795e-232a-47d9-ace4-27561091257a completed and removed from active rides
# Ride R-2c50e694-db46-46f0-b0b8-9d5ef86da8f4 started with driver D-94d6b7d9
# User U-7c28fc57 no-show for ride R-723103ef-6b5a-4124-9088-a161d1d7d25b
# Ride R-866917e3-7568-4849-b862-b2aba34678c5 started with driver D-2096ccc5
# User U-3964af56 cancelled ride R-baf11418-40e0-44bf-823d-0a3c1c51edb0 after waiting 5.0 minutes
# User U-c5fbf969 cancelled ride R-1d78049e-b90c-4b4f-ab2b-63a455308c13 after waiting 4.0 minutes
# Ride R-64dec9f9-9824-43af-aea1-0dadc7b8663f started with driver D-94c52f42
# Driver D-5354cd95 cancelled assignment to ride R-12138352-c0b0-461e-bf83-4f988fc98e4d
# Saved 9 ride_requests records to data/json/ride_requests/ride_requests_20230301_081100.json
# Saved 9 ride_requests records to data/avro/ride_requests/ride_requests_20230301_081100.avro
# Saved 911 driver_status records to data/json/driver_status/driver_status_20230301_081100.json
# Saved 911 driver_status records to data/avro/driver_status/driver_status_20230301_081100.avro
# Generated 12 ride requests at 2023-03-01 08:12:00
# Matched driver D-5354cd95 to ride R-12138352-c0b0-461e-bf83-4f988fc98e4d (distance: 0.01 km)
# Matched driver D-7a7ee719 to ride R-88e9adb4-619a-4fb2-9638-1f2c29e147f8 (distance: 0.63 km)
# Matched driver D-a4034b25 to ride R-336bada5-23a4-43a0-b0d2-c6fda6af3685 (distance: 0.07 km)
# Matched driver D-cd9bb7ae to ride R-674bd4bc-5a45-48cb-a8c5-8a235a26f2e5 (distance: 0.19 km)
# Matched driver D-5e1cce9d to ride R-b68a1cb5-20f7-4954-92c9-987f45b3d88a (distance: 2.62 km)
# Matched driver D-5a8a9482 to ride R-081af65b-9c57-4fd9-9c7a-227c64558b97 (distance: 0.49 km)
# Matched driver D-79c47742 to ride R-f153b36e-b687-47e7-8db6-a4d0995cc1b0 (distance: 0.40 km)
# Matched driver D-b9524514 to ride R-49b9acab-dbf1-4e55-aee2-9362b55eb124 (distance: 2.24 km)
# Matched driver D-c48ac9a0 to ride R-17397984-7567-47fc-81ae-3a51be4b1ad0 (distance: 1.57 km)
# Matched driver D-406d5d85 to ride R-865d8d4f-7224-4e65-a11b-6a54cc2bf40c (distance: 0.84 km)
# Matched driver D-12fac148 to ride R-b34fe44c-6bb9-4d66-8bc9-eff0ed4180ee (distance: 1.43 km)
# Driver D-13c0943d went offline
# Driver D-ab3a7aec went offline
# Driver D-1245a41f came online
# Driver D-934c4eea arrived at pickup for ride R-986c0eda-127c-48ce-8eba-0e956de8030a
# Driver D-34ac5aba went offline
# Driver D-9a67a8de came online
# Driver D-2a79fab5 arrived at pickup for ride R-c094c6a3-bcd2-4970-a0ac-c464eb1ebdd1
# Driver D-f8f5cc14 arrived at pickup for ride R-d57bd4f6-9f78-4bfd-910f-8f1c3b9a3c16
# Driver D-36bc3ec1 arrived at pickup for ride R-92f2d795-cf6d-4c8b-9788-5c9bd3b67bee
# Driver D-9b8a2045 arrived at pickup for ride R-48efb6d7-e046-418f-8ee0-53c4b33cc63d
# Driver D-8fd9f093 went offline
# Driver D-eb823f2b arrived at pickup for ride R-7b957240-9982-4b90-99e4-4c9281557d26
# Driver D-702280b8 arrived at pickup for ride R-316637a8-a636-4fb5-a5ee-ccf6b75d691b
# Driver D-54e48267 arrived at pickup for ride R-7a689553-8ea8-4c7d-a026-fc9ce0f347a5
# Driver D-490e6a5e cancelled assignment to ride R-5bcbe575-cc75-4b1f-87a2-d7d6aab45ac7
# Ride R-c094c6a3-bcd2-4970-a0ac-c464eb1ebdd1 started with driver D-2a79fab5
# Ride R-d57bd4f6-9f78-4bfd-910f-8f1c3b9a3c16 started with driver D-f8f5cc14
# Ride R-986c0eda-127c-48ce-8eba-0e956de8030a started with driver D-934c4eea
# Ride R-7a689553-8ea8-4c7d-a026-fc9ce0f347a5 started with driver D-54e48267
# Ride R-316637a8-a636-4fb5-a5ee-ccf6b75d691b started with driver D-702280b8
# User U-dfdc8a28 cancelled ride R-54648e82-ccd4-4a9c-b176-0ec51d5a4b7a after waiting 4.0 minutes
# Driver D-1b2ed87c cancelled assignment to ride R-e65adf2e-19fc-4e59-b911-edc51fca1892
# Ride R-7b957240-9982-4b90-99e4-4c9281557d26 started with driver D-eb823f2b
# Ride R-92f2d795-cf6d-4c8b-9788-5c9bd3b67bee started with driver D-36bc3ec1
# Driver D-773edcb9 cancelled assignment to ride R-dccded33-aed2-4cef-8d24-47d0eaa7030b
# Ride R-48efb6d7-e046-418f-8ee0-53c4b33cc63d started with driver D-9b8a2045
# User U-58016478 cancelled ride R-731a3ea9-ae34-4fe6-9a69-e05e02c45c70 after waiting 0.0 minutes
# Saved 12 ride_requests records to data/json/ride_requests/ride_requests_20230301_081200.json
# Saved 12 ride_requests records to data/avro/ride_requests/ride_requests_20230301_081200.avro
# Saved 908 driver_status records to data/json/driver_status/driver_status_20230301_081200.json
# Saved 908 driver_status records to data/avro/driver_status/driver_status_20230301_081200.avro
# Special event occurring at 2023-03-01 08:13:00! Demand multiplier: 1.57
# Generated 17 ride requests at 2023-03-01 08:13:00
# Matched driver D-490e6a5e to ride R-5bcbe575-cc75-4b1f-87a2-d7d6aab45ac7 (distance: 0.06 km)
# Matched driver D-1b2ed87c to ride R-e65adf2e-19fc-4e59-b911-edc51fca1892 (distance: 3.17 km)
# Matched driver D-773edcb9 to ride R-dccded33-aed2-4cef-8d24-47d0eaa7030b (distance: 2.32 km)
# Matched driver D-886b6c27 to ride R-955a0cb3-e3e7-460e-b2b9-c522de9bec21 (distance: 4.55 km)
# Matched driver D-5ef69800 to ride R-189ee23b-d76f-42d6-9660-cb42b5a77537 (distance: 9.99 km)
# Matched driver D-cba5f3aa to ride R-1237e254-5d91-4dc5-a84b-10fa671529ff (distance: 0.57 km)
# Matched driver D-3f27a575 to ride R-66c02e66-802d-45ee-8eaf-d08b7d04d3ea (distance: 2.10 km)
# Matched driver D-03e494e1 to ride R-2541d369-2c06-471c-98f5-a528c7fbcabc (distance: 0.32 km)
# Matched driver D-5406129f to ride R-0cbb8eec-e931-4a15-bf7d-851f25c41b76 (distance: 0.31 km)
# Matched driver D-33a42610 to ride R-3e538e9f-5e6d-412b-927e-a2df96d9068d (distance: 0.07 km)
# Matched driver D-cfd46df4 to ride R-1fcc6be8-c124-460a-9729-44ec35d2f4ea (distance: 2.80 km)
# Matched driver D-1075c3cb to ride R-4b388187-e08f-4969-8ed8-993ea80c94f7 (distance: 0.30 km)
# Matched driver D-8cbe972d to ride R-f19ed456-5859-4d06-9f55-fb5907b05844 (distance: 0.39 km)
# Matched driver D-87cf093b to ride R-dc9492b3-fe9e-4d70-8e4b-97bc8693ba23 (distance: 0.22 km)
# Matched driver D-497a737e to ride R-13d94fea-4bd8-475b-98f6-e1598555c250 (distance: 0.59 km)
# Matched driver D-f5ee022b to ride R-e210c261-8254-4436-a734-967fd1d6140d (distance: 0.45 km)
# Matched driver D-0e8fb7e8 to ride R-c8981b54-6dd1-4b4b-b19e-5c168e8360b2 (distance: 1.15 km)
# Driver D-3d3212c2 came online
# Driver D-42ee5cd9 arrived at pickup for ride R-6322533e-1a6b-4f4b-97f7-f0a010415862
# Driver D-cd1656d0 came online
# Driver D-cb033bfe went offline
# Driver D-d148f0e4 went offline
# Driver D-5001746e arrived at pickup for ride R-cf0bc529-09e8-4391-8db8-46915f16995f
# Driver D-dd87bd2a arrived at pickup for ride R-56493468-43fe-4a4d-b291-730619034578
# Driver D-ef775e62 came online
# Driver D-751b11e7 arrived at pickup for ride R-edd1db58-f6e2-48f8-8e97-8edf5ead28ba
# Driver D-15e84e89 arrived at pickup for ride R-e670bb87-89a7-429a-8c30-bfc2c5694d67
# Driver D-867e6aba came online
# Driver D-91222d05 arrived at pickup for ride R-ada09093-ddca-4011-a997-c4cdb9048eb0
# Driver D-0bf3a4b7 arrived at pickup for ride R-1ca5aba6-3ce3-4184-8425-9442806b9945
# Driver D-49d43f40 came online
# Driver D-a4034b25 arrived at pickup for ride R-336bada5-23a4-43a0-b0d2-c6fda6af3685
# Driver D-5354cd95 arrived at pickup for ride R-12138352-c0b0-461e-bf83-4f988fc98e4d
# Driver D-524823ae went offline
# Driver D-abfa5143 arrived at pickup for ride R-bbe749fb-831b-4ffd-9313-1080245bf7b2
# Ride R-56493468-43fe-4a4d-b291-730619034578 started with driver D-dd87bd2a
# Ride R-1ca5aba6-3ce3-4184-8425-9442806b9945 started with driver D-0bf3a4b7
# Ride R-cf0bc529-09e8-4391-8db8-46915f16995f started with driver D-5001746e
# Driver D-0b0eb8ed cancelled assignment to ride R-5396ab3a-dbd8-4c3a-8e6e-45b6c65809c2
# Ride R-bbe749fb-831b-4ffd-9313-1080245bf7b2 started with driver D-abfa5143
# Ride R-e670bb87-89a7-429a-8c30-bfc2c5694d67 started with driver D-15e84e89
# Ride R-12138352-c0b0-461e-bf83-4f988fc98e4d started with driver D-5354cd95
# Ride R-edd1db58-f6e2-48f8-8e97-8edf5ead28ba started with driver D-751b11e7
# Ride R-6322533e-1a6b-4f4b-97f7-f0a010415862 started with driver D-42ee5cd9
# User U-f8608168 no-show for ride R-ada09093-ddca-4011-a997-c4cdb9048eb0
# Ride R-336bada5-23a4-43a0-b0d2-c6fda6af3685 started with driver D-a4034b25
# Saved 17 ride_requests records to data/json/ride_requests/ride_requests_20230301_081300.json
# Saved 17 ride_requests records to data/avro/ride_requests/ride_requests_20230301_081300.avro
# Saved 909 driver_status records to data/json/driver_status/driver_status_20230301_081300.json
# Saved 909 driver_status records to data/avro/driver_status/driver_status_20230301_081300.avro
# Generated 12 ride requests at 2023-03-01 08:14:00
# Matched driver D-0b0eb8ed to ride R-5396ab3a-dbd8-4c3a-8e6e-45b6c65809c2 (distance: 2.21 km)
# Matched driver D-29bce222 to ride R-5d91c778-7b5c-4136-819c-646adad80712 (distance: 0.51 km)
# Matched driver D-ef08c2f6 to ride R-87562dfa-140a-40aa-b358-45c5c74f225b (distance: 0.52 km)
# Matched driver D-4161ed52 to ride R-19716340-c36c-4950-9f0a-da3a72dff63e (distance: 0.22 km)
# Matched driver D-0afc6c1f to ride R-20f10acc-c9b1-4fff-ae5c-c045458ca56e (distance: 0.34 km)
# Matched driver D-00378424 to ride R-2204cb4f-83e2-4753-96b7-7fcb8478f73d (distance: 0.81 km)
# Matched driver D-ebaa7b6c to ride R-560964bd-755a-4f74-903b-94c293fbd9bd (distance: 2.76 km)
# Matched driver D-cd1656d0 to ride R-c11ab61f-aa48-4559-b390-57f721ff463f (distance: 0.37 km)
# Matched driver D-b3606513 to ride R-15fb91d0-2a7c-4bd6-917f-12aaed0565af (distance: 2.35 km)
# Matched driver D-f1ef5a2a to ride R-55687984-8763-4535-b207-3ae3f929663a (distance: 0.59 km)
# Matched driver D-e265ef48 to ride R-a6399299-d4c0-4552-bbad-17ffd8cda00b (distance: 1.07 km)
# Matched driver D-467b2a72 to ride R-fc9371e5-77d4-411c-b378-71e3f5766778 (distance: 2.55 km)
# Driver D-33a42610 arrived at pickup for ride R-3e538e9f-5e6d-412b-927e-a2df96d9068d
# Driver D-538c1a30 arrived at pickup for ride R-5f9e81d2-5202-42af-bb52-0e5336e7f75f
# Driver D-1232b7ed came online
# Driver D-ecf7be8a came online
# Driver D-81b97718 came online
# Driver D-646a4fb7 completed ride R-c327fff7-5646-46b9-9b25-6b7d954fdab0
# Driver D-646a4fb7 went offline
# Driver D-4163880e came online
# Driver D-c5b01e7a went offline
# Driver D-f43a5fca arrived at pickup for ride R-9dddae35-3872-48b1-ab09-869fbeb2b851
# Driver D-0379cd51 went offline
# Driver D-750b21f5 went offline
# Driver D-5bb2465b went offline
# Driver D-b32d083d arrived at pickup for ride R-100c3d28-08b8-41d8-82ce-593740099b8b
# Driver D-39633f39 went offline
# Driver D-490e6a5e arrived at pickup for ride R-5bcbe575-cc75-4b1f-87a2-d7d6aab45ac7
# Driver D-0c3c2ce5 came online
# Driver D-5c7835bd came online
# Ride R-5bcbe575-cc75-4b1f-87a2-d7d6aab45ac7 started with driver D-490e6a5e
# Ride R-5f9e81d2-5202-42af-bb52-0e5336e7f75f started with driver D-538c1a30
# Ride R-9dddae35-3872-48b1-ab09-869fbeb2b851 started with driver D-f43a5fca
# Ride R-c327fff7-5646-46b9-9b25-6b7d954fdab0 completed and removed from active rides
# Driver D-cc801701 cancelled assignment to ride R-541623d3-ff1a-4ef7-a815-d05b2ab7efe3
# Ride R-100c3d28-08b8-41d8-82ce-593740099b8b started with driver D-b32d083d
# Ride R-3e538e9f-5e6d-412b-927e-a2df96d9068d started with driver D-33a42610
# User U-3043f34b cancelled ride R-5c2676a4-d971-4a46-be05-1346c02f87ab after waiting 0.0 minutes
# Saved 12 ride_requests records to data/json/ride_requests/ride_requests_20230301_081400.json
# Saved 12 ride_requests records to data/avro/ride_requests/ride_requests_20230301_081400.avro
# Saved 912 driver_status records to data/json/driver_status/driver_status_20230301_081400.json
# Saved 912 driver_status records to data/avro/driver_status/driver_status_20230301_081400.avro
# Generated 8 ride requests at 2023-03-01 08:15:00
# Matched driver D-cc801701 to ride R-541623d3-ff1a-4ef7-a815-d05b2ab7efe3 (distance: 0.10 km)
# Matched driver D-aaa73b77 to ride R-b4b2cd95-6755-4843-866a-8746a6fe5dee (distance: 0.52 km)
# Matched driver D-aec87438 to ride R-98e9a598-a234-49dc-9b7f-8bcfe76214da (distance: 0.97 km)
# Matched driver D-6ccce5be to ride R-bd2e2331-2a8f-452d-91dc-05ec688d387b (distance: 0.10 km)
# Matched driver D-b9f541da to ride R-36e665d4-fb86-48d8-82ed-495fcf44b3f1 (distance: 0.33 km)
# Matched driver D-7de0bbbf to ride R-ecdefc14-5eb9-4754-a0a7-72f9d86280ee (distance: 0.69 km)
# Matched driver D-445832d3 to ride R-d895c97d-7d37-4e2a-a6b5-4973c68e4a50 (distance: 1.09 km)
# Matched driver D-09cc0a22 to ride R-341cc053-f20d-4776-919b-31766ab586e4 (distance: 0.38 km)
# Driver D-ba3b6b6a went offline
# Driver D-34ac5aba came online
# Driver D-df5d7edb completed ride R-1922b476-115d-45d4-ab1f-a9ad93f28954
# Driver D-6c872b1c came online
# Driver D-cfb84c22 completed ride R-b6d74e17-9afb-40f3-8268-6b6b1eccd954
# Driver D-cd9bb7ae arrived at pickup for ride R-674bd4bc-5a45-48cb-a8c5-8a235a26f2e5
# Driver D-c9fab969 arrived at pickup for ride R-7774d943-b3d8-4935-884e-2c368fd42545
# Driver D-b0ee6bfb went offline
# Driver D-cc6ee95e went offline
# Driver D-0e0512cd came online
# Driver D-c196a1a1 came online
# Driver D-d83f8cd3 arrived at pickup for ride R-0a6d029c-2d2c-4aaa-9776-a2ff3450d6de
# Driver D-7329b86d arrived at pickup for ride R-878a7774-8a01-474f-834d-3d183e3c90d7
# Driver D-54e48267 completed ride R-7a689553-8ea8-4c7d-a026-fc9ce0f347a5
# Ride R-b6d74e17-9afb-40f3-8268-6b6b1eccd954 completed and removed from active rides
# Ride R-1922b476-115d-45d4-ab1f-a9ad93f28954 completed and removed from active rides
# Ride R-878a7774-8a01-474f-834d-3d183e3c90d7 started with driver D-7329b86d
# Ride R-7774d943-b3d8-4935-884e-2c368fd42545 started with driver D-c9fab969
# Ride R-0a6d029c-2d2c-4aaa-9776-a2ff3450d6de started with driver D-d83f8cd3
# User U-5769df9c cancelled ride R-63476bf9-b0ec-4599-ba88-5f80cb87da3f after waiting 9.0 minutes
# Ride R-7a689553-8ea8-4c7d-a026-fc9ce0f347a5 completed and removed from active rides
# Driver D-e37d9a47 cancelled assignment to ride R-902fee05-07eb-4fb4-b758-8a74dc2d72a9
# Ride R-674bd4bc-5a45-48cb-a8c5-8a235a26f2e5 started with driver D-cd9bb7ae
# Driver D-f5ee022b cancelled assignment to ride R-e210c261-8254-4436-a734-967fd1d6140d
# User U-8edd0124 cancelled ride R-379ea85b-bc7d-4f7c-9f07-7e6b49aee3a9 after waiting 0.0 minutes
# Saved 8 ride_requests records to data/json/ride_requests/ride_requests_20230301_081500.json
# Saved 8 ride_requests records to data/avro/ride_requests/ride_requests_20230301_081500.avro
# Saved 910 driver_status records to data/json/driver_status/driver_status_20230301_081500.json
# Saved 910 driver_status records to data/avro/driver_status/driver_status_20230301_081500.avro
#
# [2023-03-01 08:15:00] Simulation status:
#   Active rides: 173
#   Available drivers: 446
#   Busy drivers: 157
#   Total requests so far: 196
#   Completed rides: 5
#   Cancelled rides: 18
#   Total fare collected: $25.93
# Generated 12 ride requests at 2023-03-01 08:16:00
# Matched driver D-e37d9a47 to ride R-902fee05-07eb-4fb4-b758-8a74dc2d72a9 (distance: 0.57 km)
# Matched driver D-f5ee022b to ride R-e210c261-8254-4436-a734-967fd1d6140d (distance: 0.13 km)
# Matched driver D-bfa5d7c0 to ride R-b77864d2-ba9c-4f84-9252-47817565bfb9 (distance: 0.70 km)
# ...
# Saved 999 driver_status records to data/avro/driver_status/driver_status_20230301_195500.avro
#
# [2023-03-01 19:55:00] Simulation status:
#   Active rides: 728
#   Available drivers: 10
#   Busy drivers: 685
#   Total requests so far: 5621
#   Completed rides: 3372
#   Cancelled rides: 1521
#   Total fare collected: $82769.94
# Generated 8 ride requests at 2023-03-01 19:56:00
# Matched driver D-b1a15203 to ride R-bf9e09f9-1467-49b0-a565-684010c3ee07 (distance: 6.56 km)
# Matched driver D-b83e0ce2 to ride R-98dda64b-cca6-49ef-934e-982b0ce59b6f (distance: 2.76 km)
# Matched driver D-2ad1cb56 to ride R-9a056836-d171-417c-b217-a16b09d6b83c (distance: 1.88 km)
# Matched driver D-3a938a1c to ride R-549f1eb2-ec39-447d-8aeb-618149e132e7 (distance: 8.52 km)
# Matched driver D-673ce17e to ride R-bafa7930-7196-4a38-9b35-ba53fc3a439f (distance: 4.17 km)
# Matched driver D-77f12fe9 to ride R-7a79730b-fef4-4897-8c69-e5017d42c09f (distance: 0.77 km)
# Matched driver D-8a700f92 to ride R-7cd89470-5ed0-475a-834a-1be00ab3ebda (distance: 2.97 km)
# Matched driver D-07f28b94 to ride R-25ff3dfe-09f5-42ce-bdee-d8d78dc55f46 (distance: 5.51 km)
# Matched driver D-9904575a to ride R-2b7a9b30-a0e1-46f4-87aa-bbfcaaad2185 (distance: 1.58 km)
# Matched driver D-a5faf34c to ride R-b9663a99-c2ea-424d-a17f-386fcd24cf4e (distance: 4.02 km)
# Driver D-0532e845 completed ride R-e3d501ce-88b2-4774-aea8-6adeb76cb236
# Driver D-3a98144b completed ride R-118aff4d-2a9e-4b58-9606-2c1dee3ac9f6
# Driver D-c0d314c1 arrived at pickup for ride R-169082b6-2328-4a5a-aff4-aba85c2bac8f
# Driver D-eea93b2b arrived at pickup for ride R-251bb9c6-520f-4914-b8f3-3bc95d8e2988
# Driver D-3b1446a3 arrived at pickup for ride R-53eca709-6dd7-4933-8f07-2c4080a5e344
# Driver D-10cca1e4 arrived at pickup for ride R-4fea9f0a-cc6e-4140-b311-a1250768e1cc
# Driver D-93dc903e arrived at pickup for ride R-b4dd00c6-2c8f-446b-b04f-f965211796f3
# Driver D-ec526bca arrived at pickup for ride R-4e580169-d91a-459e-8b8e-d3325b777afa
# Driver D-0dbe54c8 completed ride R-62a969c7-abc8-49a9-8220-9bbbb546fe5d
# Driver D-af8a775c completed ride R-6d1fe227-6f23-4cb4-8db2-ecadd660a7ee
# Driver D-7298c07e completed ride R-c74e47fc-de7f-4d05-920d-cbf034cbbd72
# Driver D-25d3b144 completed ride R-9373e2c0-39a2-406c-b21f-79bbdb94dc8b
# Driver D-318bb784 completed ride R-95331443-216b-45a2-8f41-983a77674517
# Driver D-1524ace1 arrived at pickup for ride R-e82c5c93-1ac5-4907-9415-49092ca15f96
# Ride R-6d1fe227-6f23-4cb4-8db2-ecadd660a7ee completed and removed from active rides
# Ride R-95331443-216b-45a2-8f41-983a77674517 completed and removed from active rides
# Ride R-c74e47fc-de7f-4d05-920d-cbf034cbbd72 completed and removed from active rides
# Ride R-9373e2c0-39a2-406c-b21f-79bbdb94dc8b completed and removed from active rides
# Ride R-118aff4d-2a9e-4b58-9606-2c1dee3ac9f6 completed and removed from active rides
# Ride R-4e580169-d91a-459e-8b8e-d3325b777afa started with driver D-ec526bca
# Ride R-e3d501ce-88b2-4774-aea8-6adeb76cb236 completed and removed from active rides
# Ride R-251bb9c6-520f-4914-b8f3-3bc95d8e2988 started with driver D-eea93b2b
# Ride R-169082b6-2328-4a5a-aff4-aba85c2bac8f started with driver D-c0d314c1
# Ride R-53eca709-6dd7-4933-8f07-2c4080a5e344 started with driver D-3b1446a3
# Ride R-b4dd00c6-2c8f-446b-b04f-f965211796f3 started with driver D-93dc903e
# Ride R-62a969c7-abc8-49a9-8220-9bbbb546fe5d completed and removed from active rides
# Driver D-a0bd1ca7 cancelled assignment to ride R-e638b5fa-6fe1-464e-8340-5a99194504d6
# Ride R-4fea9f0a-cc6e-4140-b311-a1250768e1cc started with driver D-10cca1e4
# Ride R-e82c5c93-1ac5-4907-9415-49092ca15f96 started with driver D-1524ace1
# User U-79958404 cancelled ride R-ce143388-5a39-4937-87a0-c164ef9a0987 after waiting 1.0 minutes
# Saved 8 ride_requests records to data/json/ride_requests/ride_requests_20230301_195600.json
# Saved 8 ride_requests records to data/avro/ride_requests/ride_requests_20230301_195600.avro
# Saved 999 driver_status records to data/json/driver_status/driver_status_20230301_195600.json
# Saved 999 driver_status records to data/avro/driver_status/driver_status_20230301_195600.avro
# Generated 11 ride requests at 2023-03-01 19:57:00
# Matched driver D-a0bd1ca7 to ride R-e638b5fa-6fe1-464e-8340-5a99194504d6 (distance: 0.86 km)
# Matched driver D-0dbe54c8 to ride R-69fb51d7-df00-46bd-8c32-a7e56184c009 (distance: 2.15 km)
# Matched driver D-af8a775c to ride R-59d87ce0-1a14-42e9-919a-b81085947471 (distance: 2.31 km)
# Matched driver D-0532e845 to ride R-faf4a6a7-2d57-4119-a189-7760b224dcaf (distance: 4.03 km)
# Matched driver D-3a98144b to ride R-1e3d3ad1-1a85-4ae7-a6eb-e41ff017d015 (distance: 9.78 km)
# Matched driver D-7298c07e to ride R-0e76a223-1227-49ae-8270-12c2c077bb74 (distance: 6.98 km)
# Matched driver D-318bb784 to ride R-7d75551d-52d1-41bb-8e09-8d7d85069963 (distance: 2.32 km)
# Matched driver D-25d3b144 to ride R-fc93c1e2-0f3d-42b6-8174-8d1b1e4f0284 (distance: 1.93 km)
# Driver D-e093ed54 arrived at pickup for ride R-c24c4ecf-a23b-49e6-bcbb-f3d11fff39f7
# Driver D-39674d58 arrived at pickup for ride R-722fde25-7226-485e-a22f-9abc2ab23c52
# Driver D-b2d514ab completed ride R-4fd03040-8b31-425d-b61c-bda414f8c003
# Driver D-1cee6b23 arrived at pickup for ride R-47c89459-edec-4d30-a61b-dcfd1dd497f6
# Driver D-d82efadd arrived at pickup for ride R-ed3c9ad7-9a17-4f46-8a96-ea963ed531db
# Driver D-45b85a21 arrived at pickup for ride R-8ef461b2-b8dc-4218-8534-aba7e8ae66f5
# Driver D-711983a9 arrived at pickup for ride R-86872ef5-1d09-43a1-93d9-a2f3ee96bddc
# Driver D-15e84e89 arrived at pickup for ride R-66e0ae13-1d26-4a71-b5ab-91eec71f7bd6
# Driver D-e803839d completed ride R-571c63f5-1c10-4196-9b07-e5c66b13dca1
# Driver D-3f493900 completed ride R-ab783369-fb1a-4bc1-9b16-395faca1303e
# Driver D-ad7a04c3 arrived at pickup for ride R-6322b154-34b5-4d80-b3e0-a90330015c71
# Driver D-03e494e1 arrived at pickup for ride R-9dede76a-f3e7-44e9-ae12-c88e3f54ce0d
# Driver D-909d4018 arrived at pickup for ride R-9a9621fc-86dc-4432-a7cb-1a45c90af7e7
# Driver D-9f5f1c79 arrived at pickup for ride R-b834c0f8-b1d5-4294-8c93-e22dfbbbc4b9
# Ride R-4fd03040-8b31-425d-b61c-bda414f8c003 completed and removed from active rides
# Ride R-571c63f5-1c10-4196-9b07-e5c66b13dca1 completed and removed from active rides
# Ride R-ab783369-fb1a-4bc1-9b16-395faca1303e completed and removed from active rides
# Driver D-006274a7 cancelled assignment to ride R-191e44f1-cb0a-46c8-89de-332a1dbbf3f2
# Ride R-722fde25-7226-485e-a22f-9abc2ab23c52 started with driver D-39674d58
# Driver D-d70e60de cancelled assignment to ride R-ecb4903c-96ad-48ce-9c2c-131427d6fdd9
# Ride R-6322b154-34b5-4d80-b3e0-a90330015c71 started with driver D-ad7a04c3
# Ride R-66e0ae13-1d26-4a71-b5ab-91eec71f7bd6 started with driver D-15e84e89
# Ride R-b834c0f8-b1d5-4294-8c93-e22dfbbbc4b9 started with driver D-9f5f1c79
# Ride R-9a9621fc-86dc-4432-a7cb-1a45c90af7e7 started with driver D-909d4018
# Ride R-c24c4ecf-a23b-49e6-bcbb-f3d11fff39f7 started with driver D-e093ed54
# Ride R-9dede76a-f3e7-44e9-ae12-c88e3f54ce0d started with driver D-03e494e1
# Driver D-8673235b cancelled assignment to ride R-cb21decb-0c06-43cf-a908-9213b58daffc
# Ride R-ed3c9ad7-9a17-4f46-8a96-ea963ed531db started with driver D-d82efadd
# Ride R-86872ef5-1d09-43a1-93d9-a2f3ee96bddc started with driver D-711983a9
# Driver D-1f9a2f83 cancelled assignment to ride R-8c5861c0-73ac-441a-8931-2518c011dc75
# Driver D-7287f153 cancelled assignment to ride R-29ef9129-7331-4cbf-ab8d-925e8acb0f34
# Ride R-8ef461b2-b8dc-4218-8534-aba7e8ae66f5 started with driver D-45b85a21
# Ride R-47c89459-edec-4d30-a61b-dcfd1dd497f6 started with driver D-1cee6b23
# Driver D-e4348b66 cancelled assignment to ride R-94b911fc-9cfa-40c7-bf5b-bf823e2a784f
# User U-95bd2ff7 cancelled ride R-19392e4c-a796-4e61-a315-7c24dd558670 after waiting 5.0 minutes
# User U-64c3531a cancelled ride R-f04378b5-3b09-4853-a55f-f04da349529d after waiting 4.0 minutes
# User U-2127e64b cancelled ride R-89398360-357f-4c9e-8111-07c27e62c7bd after waiting 2.0 minutes
# Saved 11 ride_requests records to data/json/ride_requests/ride_requests_20230301_195700.json
# Saved 11 ride_requests records to data/avro/ride_requests/ride_requests_20230301_195700.avro
# Saved 999 driver_status records to data/json/driver_status/driver_status_20230301_195700.json
# Saved 999 driver_status records to data/avro/driver_status/driver_status_20230301_195700.avro
# Generated 8 ride requests at 2023-03-01 19:58:00
# Matched driver D-006274a7 to ride R-191e44f1-cb0a-46c8-89de-332a1dbbf3f2 (distance: 1.60 km)
# Matched driver D-b2d514ab to ride R-ecb4903c-96ad-48ce-9c2c-131427d6fdd9 (distance: 8.00 km)
# Matched driver D-8673235b to ride R-cb21decb-0c06-43cf-a908-9213b58daffc (distance: 1.34 km)
# Matched driver D-d70e60de to ride R-8c5861c0-73ac-441a-8931-2518c011dc75 (distance: 1.23 km)
# Matched driver D-e803839d to ride R-29ef9129-7331-4cbf-ab8d-925e8acb0f34 (distance: 0.36 km)
# Matched driver D-1f9a2f83 to ride R-94b911fc-9cfa-40c7-bf5b-bf823e2a784f (distance: 1.78 km)
# Matched driver D-7287f153 to ride R-bb636454-12ab-4b70-ba9c-20a92e12e360 (distance: 4.45 km)
# Matched driver D-e4348b66 to ride R-a43a2b94-c8bc-4356-af4e-0327195dc56c (distance: 6.26 km)
# Matched driver D-3f493900 to ride R-69690abb-8a98-4467-a479-a21f98b7ad5a (distance: 7.11 km)
# Driver D-0126b070 arrived at pickup for ride R-9aef6f29-fb33-435c-b21d-85f46e825487
# Driver D-cb91c427 arrived at pickup for ride R-80f4b725-a971-41a5-bcaa-c2bb0feebc8f
# Driver D-4e65bf52 completed ride R-50059bfe-1ea6-46b4-877a-d87e6474cce0
# Driver D-5da4558f arrived at pickup for ride R-4c158a8e-9816-4239-98a7-fb057c26f277
# Driver D-f3b1a558 completed ride R-31192c5e-5ac8-4450-8d03-fb0eddc7fe4e
# Driver D-f4d93850 completed ride R-26350485-3325-4007-837c-9972dcd6a11c
# Driver D-c196a1a1 arrived at pickup for ride R-f9b010f4-bfcf-4049-b1ef-466280bc6072
# Ride R-50059bfe-1ea6-46b4-877a-d87e6474cce0 completed and removed from active rides
# Ride R-4c158a8e-9816-4239-98a7-fb057c26f277 started with driver D-5da4558f
# User U-5c25839d no-show for ride R-80f4b725-a971-41a5-bcaa-c2bb0feebc8f
# Driver D-3b624477 cancelled assignment to ride R-c29f2c02-8a2f-484c-a9b4-f0111e7976b8
# Driver D-51518c4d cancelled assignment to ride R-9d0167e5-3a41-43bc-b8c4-4e47db5196ce
# Ride R-26350485-3325-4007-837c-9972dcd6a11c completed and removed from active rides
# Ride R-31192c5e-5ac8-4450-8d03-fb0eddc7fe4e completed and removed from active rides
# Ride R-f9b010f4-bfcf-4049-b1ef-466280bc6072 started with driver D-c196a1a1
# Driver D-1c98674c cancelled assignment to ride R-947a6287-2dd2-4ebc-a9f6-d442e80cf732
# Ride R-9aef6f29-fb33-435c-b21d-85f46e825487 started with driver D-0126b070
# Driver D-b6cd47ff cancelled assignment to ride R-e1c72dfb-fcb7-4e13-8c08-b51fec645375
# Driver D-0dbe54c8 cancelled assignment to ride R-69fb51d7-df00-46bd-8c32-a7e56184c009
# User U-2cb1fdf1 cancelled ride R-d28aacc6-e8eb-4b27-a3e2-65921e2d5c57 after waiting 4.0 minutes
# User U-2c674cf8 cancelled ride R-6013483d-51bd-4772-8117-70fefe008e97 after waiting 2.0 minutes
# User U-b3f6631a cancelled ride R-b90d787a-fdbb-4917-9adf-54100b081653 after waiting 1.0 minutes
# User U-e0fcebd4 cancelled ride R-a626690b-e904-476e-84f7-a8fafb6de781 after waiting 1.0 minutes
# User U-5ac0306f cancelled ride R-2e8d3a94-8e48-4d1d-9524-e88fc15719b5 after waiting 0.0 minutes
# Saved 8 ride_requests records to data/json/ride_requests/ride_requests_20230301_195800.json
# Saved 8 ride_requests records to data/avro/ride_requests/ride_requests_20230301_195800.avro
# Saved 999 driver_status records to data/json/driver_status/driver_status_20230301_195800.json
# Saved 999 driver_status records to data/avro/driver_status/driver_status_20230301_195800.avro
# Generated 10 ride requests at 2023-03-01 19:59:00
# Matched driver D-51518c4d to ride R-9d0167e5-3a41-43bc-b8c4-4e47db5196ce (distance: 3.48 km)
# Matched driver D-0dbe54c8 to ride R-947a6287-2dd2-4ebc-a9f6-d442e80cf732 (distance: 2.07 km)
# Matched driver D-cb91c427 to ride R-e1c72dfb-fcb7-4e13-8c08-b51fec645375 (distance: 5.78 km)
# Matched driver D-4e65bf52 to ride R-7688abea-af10-490b-968c-08e5c29a0d91 (distance: 1.38 km)
# Matched driver D-f4d93850 to ride R-9a979e15-1c61-46d9-83e4-a839b365f413 (distance: 2.90 km)
# Matched driver D-f3b1a558 to ride R-33413d90-f3bb-4102-981d-534338fa6520 (distance: 3.62 km)
# Matched driver D-1c98674c to ride R-b7cc52df-7a39-47f7-806d-bfb9a793779f (distance: 4.11 km)
# Matched driver D-b6cd47ff to ride R-30aeef3e-3d12-4fdd-901b-06c73b862d35 (distance: 0.45 km)
# Matched driver D-3b624477 to ride R-362b8b92-81d6-4167-af25-4f62098a87e5 (distance: 6.80 km)
# Driver D-9373d456 completed ride R-a0fb3522-44a5-4914-8e71-2006baa24d25
# Driver D-518e72c2 arrived at pickup for ride R-13c9cd0b-34bb-4541-a367-f044ce47f10c
# Driver D-d148f0e4 arrived at pickup for ride R-a88f32ff-1de9-478c-a485-0353c323cd53
# Driver D-e44c6dd7 arrived at pickup for ride R-c70e237a-a01c-470f-8ab6-8a994630278f
# Driver D-14dac7a6 completed ride R-48caa2f2-6a65-4cba-a33e-5f733bab9eca
# Driver D-a8a46b48 completed ride R-a8a8ead5-f451-4777-bfa3-906a32d9bfa2
# Driver D-10de7164 completed ride R-8c8fc831-49f8-4224-ade5-9598e4dc40fd
# Driver D-b0116cdc arrived at pickup for ride R-0dfcc376-17a8-49f2-8a9e-98c6c6642d04
# Driver D-d53bc8b6 completed ride R-bc92a43d-8088-4b30-a212-0bc11c1e3407
# Driver D-1e8337ee completed ride R-b51fd347-8a9f-46b7-9b7b-3d7c270ce3e2
# Ride R-a8a8ead5-f451-4777-bfa3-906a32d9bfa2 completed and removed from active rides
# Ride R-bc92a43d-8088-4b30-a212-0bc11c1e3407 completed and removed from active rides
# Ride R-8c8fc831-49f8-4224-ade5-9598e4dc40fd completed and removed from active rides
# Driver D-07cc751e cancelled assignment to ride R-2f20791b-cc47-4754-b9ab-ce8fb4906c85
# Ride R-13c9cd0b-34bb-4541-a367-f044ce47f10c started with driver D-518e72c2
# Driver D-b2d514ab cancelled assignment to ride R-ecb4903c-96ad-48ce-9c2c-131427d6fdd9
# Ride R-b51fd347-8a9f-46b7-9b7b-3d7c270ce3e2 completed and removed from active rides
# Driver D-20fba3f3 cancelled assignment to ride R-33de4478-076d-4d6a-9a17-439773933b23
# Ride R-a0fb3522-44a5-4914-8e71-2006baa24d25 completed and removed from active rides
# User U-a17ece9e cancelled ride R-c29f2c02-8a2f-484c-a9b4-f0111e7976b8 after waiting 63.0 minutes
# Ride R-a88f32ff-1de9-478c-a485-0353c323cd53 started with driver D-d148f0e4
# Ride R-48caa2f2-6a65-4cba-a33e-5f733bab9eca completed and removed from active rides
# Driver D-650ef016 cancelled assignment to ride R-cc2f9850-6565-41e8-a223-5dde4cd927ac
# Ride R-0dfcc376-17a8-49f2-8a9e-98c6c6642d04 started with driver D-b0116cdc
# Ride R-c70e237a-a01c-470f-8ab6-8a994630278f started with driver D-e44c6dd7
# Driver D-618aa783 cancelled assignment to ride R-7f30756d-c608-4478-a6e8-6233ca1ca455
# User U-804377d5 cancelled ride R-c81b752f-061d-4642-929d-47268566d16e after waiting 4.0 minutes
# User U-66f9e6f1 cancelled ride R-2d33942e-0f74-4ec7-a632-edfb1a0104d9 after waiting 4.0 minutes
# User U-715b8179 cancelled ride R-5705e33d-0b30-4d63-9b91-f4d544cfacad after waiting 2.0 minutes
# User U-229f9c98 cancelled ride R-3e2b8758-a4e9-4bcf-a3aa-5a19d8306dfa after waiting 1.0 minutes
# Saved 10 ride_requests records to data/json/ride_requests/ride_requests_20230301_195900.json
# Saved 10 ride_requests records to data/avro/ride_requests/ride_requests_20230301_195900.avro
# Saved 999 driver_status records to data/json/driver_status/driver_status_20230301_195900.json
# Saved 999 driver_status records to data/avro/driver_status/driver_status_20230301_195900.avro
#
# ==================================================
# Simulation completed: 2023-03-01 08:00:00 to 2023-03-01 20:00:00
# Total duration: 720 minutes
# Total ride requests: 5658
# Completed rides: 3391
# Cancelled rides: 1536
# Total fare collected: $83381.47
# Average wait time: 0.00 minutes
# Average ride duration: 0.00 minutes
# Generated 2876 data files
# ==================================================
#
# Simulation results saved to simulation_results\simulation_results.json
# Summary report saved to simulation_results\simulation_summary.txt
#
# Simulation completed successfully!
# Generated 2876 data files
# Processed 5658 ride requests
# Completed 3391 rides
# Total revenue: $83381.47
